# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/pfe/blob/main/MCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score

from mlxtend.feature_selection import SequentialFeatureSelector as SFS
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy 
import sklearn.metrics as metrics
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # CS_longia _ R1 :_

# %%
Cl1 = '/content/Classeurcc.xlsx'
data1= pd.read_excel(Cl1,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True)

# %%
del data1["Source"]
del data1["CodeSite"]
del data1["VarT_ann_IRM"]
del data1["VarT_tri_TempJ"]
del data1["VarT_tri_TempN"]
del data1["VarT_tri_NDVI"]
del data1["VarT_tri_EVI"]
del data1["Bio_Ta_moy"]
del data1["Bio_Tint"]
del data1["Bio_Tfr_Moy"]
del data1["Bio_Pre_Ann"]
del data1["Bio_Pre_Qfr"]
del data1["Tmax_Janv"]
del data1["Bio_Tj_Moy"]
del data1["Min_TempN"]
data1.head()
# Out:
#      X_long     Y_lat  Cs_longia  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0 -15.91142  23.79474          1  ...       5.4       5.5       4.9
# 1 -13.18837  27.13295          1  ...       4.3       3.7       3.8
# 2 -13.18837  27.13295          1  ...       4.3       3.7       3.8
# 3 -13.18562  27.15794          0  ...       4.1       3.7       3.9
# 4 -13.16718  27.15773          0  ...       4.2       3.6       3.8
#
# [5 rows x 213 columns]

# %%
X1 = data1.loc[:, data1.columns != 'Cs_longia']
y1 = data1.Cs_longia

# %%
X1
# Out:
#         X_long      Y_lat    Bovins  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740  0.000000  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 3   -13.185620  27.157940  0.000000  ...       4.1       3.7       3.9
# 4   -13.167180  27.157730  0.000000  ...       4.2       3.6       3.8
# ..         ...        ...       ...  ...       ...       ...       ...
# 255  -5.366667  35.766667  8.495770  ...       4.0       4.0       4.2
# 256  -5.816667  35.783333  0.000000  ...       3.6       3.8       4.0
# 257  -5.366667  35.833333  7.411978  ...       4.0       3.9       4.3
# 258  -5.558611  35.841944  5.696193  ...       3.6       3.4       3.6
# 259  -5.483333  35.900000  6.839514  ...       4.0       4.0       4.2
#
# [260 rows x 212 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC

classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1.5,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
def tp(y_true, y_pred): 
    error= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
    return error

my_scorer = make_scorer(tp, greater_is_better=True)
my_scorer = make_scorer(tp, greater_is_better=True)
def tp1(y_true, y_pred): 
    MCC= matthews_corrcoef(y_true, y_pred)
    return MCC

my_scorer1 = make_scorer(tp1, greater_is_better=True)
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    fig, ax = plt.subplots(figsize=(11, 5))
    for i, (train, test) in enumerate(cv.split(X1, y1)):
         clf.fit(X1.loc[train,], y1.loc[train,])
         viz = plot_roc_curve(clf, X1.loc[test,], y1.loc[test,],
                         name='ROC fold {}'.format(i),
                         alpha=0.3, lw=1, ax=ax)
         interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
         interp_tpr[0] = 0.0
         tprs.append(interp_tpr)
         aucs.append(viz.roc_auc)

    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=2, alpha=.8)

    ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="courbe roc %s " %name)
    ax.legend(loc="lower right")
    plt.show()
    # evaluate model
    scores = cross_val_score(clf, X1, y1, scoring='accuracy', cv=cv, n_jobs=-1)
    scores1 = cross_val_score(clf, X1, y1, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf, X1, y1, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X1, y1, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X1, y1, scoring=my_scorer1, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
# Out:
# XGBClassifier
# Accuracy: [0.76923077 0.75       0.73076923 0.55769231 0.65384615]
# moy_accuracy: 0.69
# precision: [0.82608696 0.75862069 0.78571429 0.4        0.61538462]
# moy_precision: 0.68
# sensibilité : [0.7037037  0.78571429 0.73333333 0.55555556 0.66666667]
# moy_sensibilité: 0.69
# spécificité : [0.84       0.70833333 0.72727273 0.55882353 0.64285714]
# moy_spécificité: 0.70
# MCC : [0.54695458 0.49589591 0.45647498 0.10891067 0.3086067 ]
# MCC: 0.38
# LogisticRegression
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Accuracy: [0.57692308 0.71153846 0.63461538 0.59615385 0.69230769]
# moy_accuracy: 0.64
# precision: [0.63157895 0.72413793 0.68965517 0.42105263 0.66666667]
# moy_precision: 0.63
# sensibilité : [0.44444444 0.75       0.66666667 0.44444444 0.66666667]
# moy_sensibilité: 0.59
# spécificité : [0.72       0.66666667 0.59090909 0.67647059 0.71428571]
# moy_spécificité: 0.67
# MCC : [0.1706229  0.41822547 0.2562206  0.11945993 0.38095238]
# MCC: 0.27
# RandomForestClassifier
# Accuracy: [0.63461538 0.65384615 0.69230769 0.55769231 0.65384615]
# moy_accuracy: 0.64
# precision: [0.66666667 0.70833333 0.81818182 0.36842105 0.625     ]
# moy_precision: 0.64
# sensibilité : [0.59259259 0.60714286 0.6        0.38888889 0.625     ]
# moy_sensibilité: 0.56
# spécificité : [0.68       0.70833333 0.81818182 0.64705882 0.67857143]
# moy_spécificité: 0.71
# MCC : [0.27320038 0.31547619 0.41818182 0.03551511 0.30357143]
# MCC: 0.27
# GradientBoostingClassifier
# Accuracy: [0.71153846 0.73076923 0.71153846 0.61538462 0.61538462]
# moy_accuracy: 0.68
# precision: [0.75       0.76923077 0.82608696 0.45454545 0.58333333]
# moy_precision: 0.68
# sensibilité : [0.66666667 0.71428571 0.63333333 0.55555556 0.58333333]
# moy_sensibilité: 0.63
# spécificité : [0.76       0.75       0.81818182 0.64705882 0.64285714]
# moy_spécificité: 0.72
# MCC : [0.42761799 0.46291005 0.44913963 0.19510752 0.22619048]
# MCC: 0.35
# GaussianNB
# Accuracy: [0.55769231 0.65384615 0.59615385 0.53846154 0.63461538]
# moy_accuracy: 0.60
# precision: [0.56666667 0.65625    0.61538462 0.38461538 0.6       ]
# moy_precision: 0.56
# sensibilité : [0.62962963 0.75       0.8        0.55555556 0.625     ]
# moy_sensibilité: 0.67
# spécificité : [0.48       0.54166667 0.31818182 0.52941176 0.64285714]
# moy_spécificité: 0.50
# MCC : [0.11086842 0.2988694  0.13483997 0.08084521 0.26726124]
# MCC: 0.18
# KNeighborsClassifier
# Accuracy: [0.57692308 0.67307692 0.53846154 0.61538462 0.67307692]
# moy_accuracy: 0.62
# precision: [0.69230769 0.76190476 0.6875     0.45       0.76923077]
# moy_precision: 0.67
# sensibilité : [0.33333333 0.57142857 0.36666667 0.5        0.41666667]
# moy_sensibilité: 0.44
# spécificité : [0.84       0.79166667 0.77272727 0.67647059 0.89285714]
# moy_spécificité: 0.79
# MCC : [0.2        0.36890513 0.1492123  0.17256712 0.35634832]
# MCC: 0.25

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1.5,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    # evaluate model
    scores1 = cross_val_score(clf, X1, y1, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.68
# LogisticRegression
# accuracy: 0.64
# RandomForestClassifier
# accuracy: 0.68
# GradientBoostingClassifier
# accuracy: 0.68
# GaussianNB
# accuracy: 0.60
# KNeighborsClassifier
# accuracy: 0.64

# %% [markdown]
# # Partie 2 :

# %%
Cs = '/content/Classeurcc.xlsx'
data2= pd.read_excel(Cs,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True)

# %%
del data2["Source"]
del data2["CodeSite"]
data2.head()
# Out:
#      X_long     Y_lat  Cs_longia  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0 -15.91142  23.79474          1  ...       5.4       5.5       4.9
# 1 -13.18837  27.13295          1  ...       4.3       3.7       3.8
# 2 -13.18837  27.13295          1  ...       4.3       3.7       3.8
# 3 -13.18562  27.15794          0  ...       4.1       3.7       3.9
# 4 -13.16718  27.15773          0  ...       4.2       3.6       3.8
#
# [5 rows x 226 columns]

# %%
X2 = data2.loc[:, data2.columns != 'Cs_longia']
y2 = data2.Cs_longia

# %%
X2
# Out:
#         X_long      Y_lat    Bovins  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740  0.000000  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 3   -13.185620  27.157940  0.000000  ...       4.1       3.7       3.9
# 4   -13.167180  27.157730  0.000000  ...       4.2       3.6       3.8
# ..         ...        ...       ...  ...       ...       ...       ...
# 255  -5.366667  35.766667  8.495770  ...       4.0       4.0       4.2
# 256  -5.816667  35.783333  0.000000  ...       3.6       3.8       4.0
# 257  -5.366667  35.833333  7.411978  ...       4.0       3.9       4.3
# 258  -5.558611  35.841944  5.696193  ...       3.6       3.4       3.6
# 259  -5.483333  35.900000  6.839514  ...       4.0       4.0       4.2
#
# [260 rows x 225 columns]

# %%
y2
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 255    1
# 256    1
# 257    1
# 258    1
# 259    1
# Name: Cs_longia, Length: 260, dtype: int64

# %%
selected_feat2 =["Amp3_TempJ","Max_IRM","VarT_Cy_IRM","Amp2_TempJ","VarT_tri_IRM","Vent_Aout","Prec_Juill","Prec_Mars","Amp3_IRM","Prec_Sept","Geom_Shan","Autres","Ph3_NDVI","Var_EVI","VegCul","Pl_herb","Ph1_IRM","Coniferes","Bovins","Max_NDVI","Min_EVI","Geom_unif","Elev_sd","Prec_Aout","IR_sd","Amp1_IRM","Moy_IRM","Volaille","Sol_pH_KCL","Prec_Fev","Amp2_IRM","Sol_Argile","Vent_Fev","Vent_Mars","Ph3_IRM","Substratum","VarT_tri_TempN","VarT_tri_TempJ"]

# %%
X2=X2[selected_feat2]

# %%
X2
# Out:
#      Amp3_TempJ  Max_IRM  ...  VarT_tri_TempN  VarT_tri_TempJ
# 0             7     3950  ...               0               0
# 1            31     4660  ...               1               1
# 2            31     4660  ...               1               1
# 3            23     4140  ...               1               0
# 4            33     3540  ...               0               1
# ..          ...      ...  ...             ...             ...
# 255           5     1950  ...               0               0
# 256           1     2690  ...               0               0
# 257           6     2430  ...               0               0
# 258           0     1530  ...               0               0
# 259           2     1870  ...               0               0
#
# [260 rows x 38 columns]

# %%
y2
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 255    1
# 256    1
# 257    1
# 258    1
# 259    1
# Name: Cs_longia, Length: 260, dtype: int64

# %%
from sklearn.metrics import matthews_corrcoef
classifiers = {
    "XGBClassifier":  XGBClassifier(scale_pos_weight=1.5,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(learning_rate=0.1, n_estimators=10, random_state=11),
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
def tp(y_true, y_pred): 
    error= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
    return error

my_scorer = make_scorer(tp, greater_is_better=True)
def tp1(y_true, y_pred): 
    MCC= matthews_corrcoef(y_true, y_pred)
    return MCC

my_scorer1 = make_scorer(tp1, greater_is_better=True)
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    fig, ax = plt.subplots(figsize=(11, 5))
    for i, (train, test) in enumerate(cv.split(X2, y2)):
         clf.fit(X2.loc[train,], y2.loc[train,])
         viz = plot_roc_curve(clf, X2.loc[test,], y2.loc[test,],
                         name='ROC fold {}'.format(i),
                         alpha=0.3, lw=1, ax=ax)
         interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
         interp_tpr[0] = 0.0
         tprs.append(interp_tpr)
         aucs.append(viz.roc_auc)

    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=2, alpha=.8)

    ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="courbe roc %s " %name)
    ax.legend(loc="lower right")
    plt.show()
    # evaluate model
    scores = cross_val_score(clf, X2, y2, scoring='accuracy', cv=cv, n_jobs=-1)
    scores1 = cross_val_score(clf, X2, y2, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf, X2, y2, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X2, y2, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X2, y2, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
# Out:
# XGBClassifier
# Accuracy: [0.65384615 0.67307692 0.73076923 0.40384615 0.65384615]
# moy_accuracy: 0.62
# precision: [0.66666667 0.68965517 0.83333333 0.27586207 0.61538462]
# moy_precision: 0.62
# sensibilité : [0.66666667 0.71428571 0.66666667 0.44444444 0.66666667]
# moy_sensibilité: 0.63
# spécificité : [0.64       0.625      0.81818182 0.38235294 0.64285714]
# moy_spécificité: 0.62
# MCC : [ 0.30666667  0.34055503  0.48049998 -0.16590797  0.3086067 ]
# MCC: 0.25
# LogisticRegression
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Accuracy: [0.67307692 0.75       0.67307692 0.55769231 0.65384615]
# moy_accuracy: 0.66
# precision: [0.66666667 0.74193548 0.76       0.36842105 0.61538462]
# moy_precision: 0.63
# sensibilité : [0.74074074 0.82142857 0.63333333 0.38888889 0.66666667]
# moy_sensibilité: 0.65
# spécificité : [0.6        0.66666667 0.72727273 0.64705882 0.64285714]
# moy_spécificité: 0.66
# MCC : [0.34459104 0.49590526 0.35657682 0.03551511 0.3086067 ]
# MCC: 0.31
# RandomForestClassifier
# Accuracy: [0.69230769 0.71153846 0.67307692 0.5        0.65384615]
# moy_accuracy: 0.65
# precision: [0.72       0.74074074 0.7826087  0.31818182 0.65      ]
# moy_precision: 0.64
# sensibilité : [0.66666667 0.71428571 0.6        0.38888889 0.54166667]
# moy_sensibilité: 0.58
# spécificité : [0.72       0.70833333 0.77272727 0.55882353 0.75      ]
# moy_spécificité: 0.70
# MCC : [ 0.38666667  0.42167885  0.37076627 -0.05035033  0.2988694 ]
# MCC: 0.29
# GradientBoostingClassifier
# Accuracy: [0.73076923 0.76923077 0.71153846 0.53846154 0.69230769]
# moy_accuracy: 0.69
# precision: [0.7826087  0.83333333 0.85714286 0.35       0.68181818]
# moy_precision: 0.70
# sensibilité : [0.66666667 0.71428571 0.6        0.38888889 0.625     ]
# moy_sensibilité: 0.60
# spécificité : [0.8        0.83333333 0.86363636 0.61764706 0.75      ]
# moy_spécificité: 0.77
# MCC : [0.46945693 0.54761905 0.46683022 0.00639137 0.37839373]
# MCC: 0.37
# GaussianNB
# Accuracy: [0.55769231 0.65384615 0.67307692 0.53846154 0.51923077]
# moy_accuracy: 0.59
# precision: [0.5625     0.64705882 0.72413793 0.375      0.48387097]
# moy_precision: 0.56
# sensibilité : [0.66666667 0.78571429 0.7        0.5        0.625     ]
# moy_sensibilité: 0.66
# spécificité : [0.44       0.5        0.63636364 0.55882353 0.42857143]
# moy_spécificité: 0.51
# MCC : [0.10954451 0.29939248 0.33459395 0.05613609 0.05442863]
# MCC: 0.17
# KNeighborsClassifier
# Accuracy: [0.67307692 0.65384615 0.53846154 0.61538462 0.51923077]
# moy_accuracy: 0.60
# precision: [0.75       0.8125     0.65       0.45       0.46666667]
# moy_precision: 0.63
# sensibilité : [0.55555556 0.46428571 0.43333333 0.5        0.29166667]
# moy_sensibilité: 0.45
# spécificité : [0.8        0.875      0.68181818 0.67647059 0.71428571]
# moy_spécificité: 0.75
# MCC : [0.36514837 0.36647046 0.11693692 0.17256712 0.00654981]
# MCC: 0.21

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1.5,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    # evaluate model
    scores1 = cross_val_score(clf, X2, y2, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.65
# LogisticRegression
# accuracy: 0.67
# RandomForestClassifier
# accuracy: 0.67
# GradientBoostingClassifier
# accuracy: 0.65
# GaussianNB
# accuracy: 0.61
# KNeighborsClassifier
# accuracy: 0.62

# %% [markdown]
# # Partie 3

# %%
Cl = '/content/Classeurcc.xlsx'
data3= pd.read_excel(Cl,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True)

# %%
selected_feat_XGB = ['Coniferes', 'ZonePel', 'Lesfeuillus', 'VegInond', 'Amp2_IRM',
       'VarT_tri_IRM', 'Amp1_TempJ', 'VarT_ann_NDVI', 'Bio_Pre_sec', 'Rad_Dec',
       'Tmax_Mars', 'Tmax_Avril', 'Vap_Sept', 'Vent_Mars', 'Vent_Juin']

# %%
X3 = data3.loc[:, data3.columns != 'Cs_longia']

# %%
X3
# Out:
#        Source     CodeSite     X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0    Bennouna  Z01-S01-G01 -15.911420  ...       5.4       5.5       4.9
# 1    Bennouna  Z01-S05-G01 -13.188370  ...       4.3       3.7       3.8
# 2    Bennouna  Z01-S05-G02 -13.188370  ...       4.3       3.7       3.8
# 3    Bennouna  Z01-S07-G01 -13.185620  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.167180  ...       4.2       3.6       3.8
# ..        ...          ...        ...  ...       ...       ...       ...
# 255     Trari    Trari_269  -5.366667  ...       4.0       4.0       4.2
# 256     Trari    Trari_270  -5.816667  ...       3.6       3.8       4.0
# 257     Trari    Trari_273  -5.366667  ...       4.0       3.9       4.3
# 258     Trari    Trari_274  -5.558611  ...       3.6       3.4       3.6
# 259     Trari    Trari_275  -5.483333  ...       4.0       4.0       4.2
#
# [260 rows x 227 columns]

# %%
X3=X3[selected_feat_XGB]

# %%
X3
# Out:
#      Coniferes  ZonePel  Lesfeuillus  ...  Vap_Sept  Vent_Mars  Vent_Juin
# 0            0        3            0  ...      2.16        6.1        7.1
# 1            0        0            0  ...      2.09        4.8        6.4
# 2            0        0            0  ...      2.09        4.8        6.4
# 3            0        0            0  ...      2.10        5.1        6.2
# 4            0        0            0  ...      2.13        5.0        5.7
# ..         ...      ...          ...  ...       ...        ...        ...
# 255          0        0            0  ...      1.93        4.6        3.9
# 256          0        0            0  ...      1.92        4.6        3.7
# 257          0        0            0  ...      1.93        4.5        4.0
# 258          0       58            0  ...      1.98        4.6        4.1
# 259          0        5           22  ...      1.95        4.7        3.8
#
# [260 rows x 15 columns]

# %%
y3 = data3.Cs_longia

# %%
y3
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 255    1
# 256    1
# 257    1
# 258    1
# 259    1
# Name: Cs_longia, Length: 260, dtype: int64

# %%
classifiers = {
    "XGBClassifier":  XGBClassifier(scale_pos_weight=1.5,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(learning_rate=0.1, n_estimators=10, random_state=11),
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
def tp(y_true, y_pred): 
    error= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
    return error

my_scorer = make_scorer(tp, greater_is_better=True)
def tp1(y_true, y_pred): 
    MCC= matthews_corrcoef(y_true, y_pred)
    return MCC

my_scorer1 = make_scorer(tp1, greater_is_better=True)
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    fig, ax = plt.subplots(figsize=(11, 5))
    for i, (train, test) in enumerate(cv.split(X3, y3)):
         clf.fit(X3.loc[train,], y3.loc[train,])
         viz = plot_roc_curve(clf, X3.loc[test,], y3.loc[test,],
                         name='ROC fold {}'.format(i),
                         alpha=0.3, lw=1, ax=ax)
         interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
         interp_tpr[0] = 0.0
         tprs.append(interp_tpr)
         aucs.append(viz.roc_auc)

    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=2, alpha=.8)

    ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="courbe roc %s " %name)
    ax.legend(loc="lower right")
    plt.show()
    # evaluate model
    scores = cross_val_score(clf, X3, y3, scoring='accuracy', cv=cv, n_jobs=-1)
    scores1 = cross_val_score(clf, X3, y3, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf, X3, y3, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X3, y3, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X3, y3, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
# Out:
# XGBClassifier
# Accuracy: [0.71153846 0.76923077 0.65384615 0.5        0.67307692]
# moy_accuracy: 0.66
# precision: [0.75       0.78571429 0.71428571 0.31818182 0.62962963]
# moy_precision: 0.64
# sensibilité : [0.66666667 0.78571429 0.66666667 0.38888889 0.70833333]
# moy_sensibilité: 0.64
# spécificité : [0.76       0.75       0.63636364 0.55882353 0.64285714]
# moy_spécificité: 0.67
# MCC : [ 0.42761799  0.53571429  0.30031249 -0.05035033  0.35040918]
# MCC: 0.31
# LogisticRegression
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Accuracy: [0.57692308 0.67307692 0.59615385 0.59615385 0.63461538]
# moy_accuracy: 0.62
# precision: [0.60869565 0.68965517 0.65517241 0.41176471 0.63157895]
# moy_precision: 0.60
# sensibilité : [0.51851852 0.71428571 0.63333333 0.38888889 0.5       ]
# moy_sensibilité: 0.55
# spécificité : [0.64       0.625      0.54545455 0.70588235 0.75      ]
# moy_spécificité: 0.65
# MCC : [0.15946632 0.34055503 0.17784724 0.09611558 0.25881585]
# MCC: 0.21
# RandomForestClassifier
# Accuracy: [0.65384615 0.71153846 0.69230769 0.53846154 0.69230769]
# moy_accuracy: 0.66
# precision: [0.71428571 0.7826087  0.79166667 0.35       0.72222222]
# moy_precision: 0.67
# sensibilité : [0.55555556 0.64285714 0.63333333 0.38888889 0.54166667]
# moy_sensibilité: 0.55
# spécificité : [0.76       0.79166667 0.77272727 0.61764706 0.82142857]
# moy_spécificité: 0.75
# MCC : [0.3213196  0.43614942 0.40241873 0.00639137 0.38047794]
# MCC: 0.31
# GradientBoostingClassifier
# Accuracy: [0.67307692 0.71153846 0.67307692 0.53846154 0.75      ]
# moy_accuracy: 0.67
# precision: [0.85714286 0.84210526 0.80952381 0.375      0.78947368]
# moy_precision: 0.73
# sensibilité : [0.44444444 0.57142857 0.56666667 0.5        0.625     ]
# moy_sensibilité: 0.54
# spécificité : [0.92       0.875      0.81818182 0.55882353 0.85714286]
# moy_spécificité: 0.81
# MCC : [0.41051346 0.46217117 0.3874996  0.05613609 0.49914486]
# MCC: 0.36
# GaussianNB
# Accuracy: [0.59615385 0.59615385 0.57692308 0.59615385 0.55769231]
# moy_accuracy: 0.58
# precision: [0.60714286 0.58536585 0.58333333 0.41176471 0.52173913]
# moy_precision: 0.54
# sensibilité : [0.62962963 0.85714286 0.93333333 0.38888889 0.5       ]
# moy_sensibilité: 0.66
# spécificité : [0.56       0.29166667 0.09090909 0.70588235 0.60714286]
# moy_spécificité: 0.45
# MCC : [0.19005244 0.18164652 0.04494666 0.09611558 0.10754369]
# MCC: 0.12
# KNeighborsClassifier
# Accuracy: [0.67307692 0.69230769 0.63461538 0.63461538 0.71153846]
# moy_accuracy: 0.67
# precision: [0.77777778 0.77272727 0.92307692 0.46666667 0.73684211]
# moy_precision: 0.74
# sensibilité : [0.51851852 0.60714286 0.4        0.38888889 0.58333333]
# moy_sensibilité: 0.50
# spécificité : [0.84       0.79166667 0.95454545 0.76470588 0.82142857]
# moy_spécificité: 0.83
# MCC : [0.37651976 0.40241873 0.40451992 0.16128933 0.41903519]
# MCC: 0.35

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1.5,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    # evaluate model
    scores1 = cross_val_score(clf, X3, y3, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.69
# LogisticRegression
# accuracy: 0.62
# RandomForestClassifier
# accuracy: 0.70
# GradientBoostingClassifier
# accuracy: 0.72
# GaussianNB
# accuracy: 0.59
# KNeighborsClassifier
# accuracy: 0.66

# %% [markdown]
# # Cx_pipiens :

# %%
Cl1 = '/content/Classeura1.xlsx'
datac= pd.read_excel(Cl1,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True)

# %%
del datac["Source"]
del datac["CodeSite"]
del datac["VarT_ann_IRM"]
del datac["VarT_tri_TempJ"]
del datac["VarT_tri_TempN"]
del datac["VarT_tri_NDVI"]
del datac["VarT_tri_EVI"]
del datac["Bio_Ta_moy"]
del datac["Bio_Tint"]
del datac["Bio_Tfr_Moy"]
del datac["Bio_Pre_Ann"]
del datac["Bio_Pre_Qfr"]
del datac["Tmax_Janv"]
del datac["Bio_Tj_Moy"]
del datac["Min_TempN"]
datac.head()
# Out:
#      X_long     Y_lat  Cx_pipiens  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0 -15.91142  23.79474           0  ...       5.4       5.5       4.9
# 1 -13.18837  27.13295           0  ...       4.3       3.7       3.8
# 2 -13.18837  27.13295           0  ...       4.3       3.7       3.8
# 3 -13.18562  27.15794           1  ...       4.1       3.7       3.9
# 4 -13.16718  27.15773           1  ...       4.2       3.6       3.8
#
# [5 rows x 213 columns]

# %%
X4 = datac.loc[:, datac.columns != 'Cx_pipiens']
y4 = datac.Cx_pipiens

# %%
X4
# Out:
#         X_long      Y_lat    Bovins  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740  0.000000  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 3   -13.185620  27.157940  0.000000  ...       4.1       3.7       3.9
# 4   -13.167180  27.157730  0.000000  ...       4.2       3.6       3.8
# ..         ...        ...       ...  ...       ...       ...       ...
# 355  -5.833954  35.759465  0.000000  ...       3.5       3.8       3.9
# 356  -5.366667  35.766667  8.495770  ...       4.0       4.0       4.2
# 357  -5.360864  35.801733  7.097884  ...       4.0       3.9       3.8
# 358  -5.366667  35.833333  7.411978  ...       4.0       3.9       4.3
# 359  -5.483333  35.900000  6.839514  ...       4.0       4.0       4.2
#
# [360 rows x 212 columns]

# %%
y4
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 355    1
# 356    1
# 357    1
# 358    1
# 359    1
# Name: Cx_pipiens, Length: 360, dtype: int64

# %%
classifiers = {
    "XGBClassifier":  XGBClassifier(scale_pos_weight=0.41,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(learning_rate=0.1, n_estimators=10, random_state=11),
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
def tp(y_true, y_pred): 
    error= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
    return error

my_scorer = make_scorer(tp, greater_is_better=True)
def tp1(y_true, y_pred): 
    MCC= matthews_corrcoef(y_true, y_pred)
    return MCC

my_scorer1 = make_scorer(tp1, greater_is_better=True)
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    fig, ax = plt.subplots(figsize=(11, 5))
    for i, (train, test) in enumerate(cv.split(X4, y4)):
         clf.fit(X4.loc[train,], y4.loc[train,])
         viz = plot_roc_curve(clf, X4.loc[test,], y4.loc[test,],
                         name='ROC fold {}'.format(i),
                         alpha=0.3, lw=1, ax=ax)
         interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
         interp_tpr[0] = 0.0
         tprs.append(interp_tpr)
         aucs.append(viz.roc_auc)

    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=2, alpha=.8)

    ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="courbe roc %s " %name)
    ax.legend(loc="lower right")
    plt.show()
    # evaluate model
    scores = cross_val_score(clf, X4, y4, scoring='accuracy', cv=cv, n_jobs=-1)
    scores1 = cross_val_score(clf, X4, y4, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf, X4, y4, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X4, y4, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X4, y4, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
# Out:
# XGBClassifier
# Accuracy: [0.72222222 0.66666667 0.75       0.73611111 0.76388889]
# moy_accuracy: 0.73
# precision: [0.78571429 0.75       0.8        0.86       0.83673469]
# moy_precision: 0.81
# sensibilité : [0.84615385 0.78       0.83333333 0.78181818 0.82      ]
# moy_sensibilité: 0.81
# spécificité : [0.4        0.40909091 0.58333333 0.58823529 0.63636364]
# moy_spécificité: 0.52
# MCC : [0.26519742 0.19446897 0.42640143 0.34117245 0.45086385]
# MCC: 0.34
# LogisticRegression
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Accuracy: [0.63888889 0.55555556 0.56944444 0.58333333 0.63888889]
# moy_accuracy: 0.60
# precision: [0.80952381 0.76470588 0.70731707 0.80487805 0.8       ]
# moy_precision: 0.78
# sensibilité : [0.65384615 0.52       0.60416667 0.6        0.64      ]
# moy_sensibilité: 0.60
# spécificité : [0.6        0.63636364 0.5        0.52941176 0.63636364]
# moy_spécificité: 0.58
# MCC : [0.23062266 0.14427824 0.09917044 0.11099586 0.25619595]
# MCC: 0.17
# RandomForestClassifier
# Accuracy: [0.76388889 0.68055556 0.69444444 0.73611111 0.76388889]
# moy_accuracy: 0.73
# precision: [0.76119403 0.70769231 0.70967742 0.78125    0.7704918 ]
# moy_precision: 0.75
# sensibilité : [0.98076923 0.92       0.91666667 0.90909091 0.94      ]
# moy_sensibilité: 0.93
# spécificité : [0.2        0.13636364 0.25       0.17647059 0.36363636]
# moy_spécificité: 0.23
# MCC : [0.31850685 0.08763743 0.22718473 0.11562432 0.38876653]
# MCC: 0.23
# GradientBoostingClassifier
# Accuracy: [0.70833333 0.68055556 0.69444444 0.68055556 0.69444444]
# moy_accuracy: 0.69
# precision: [0.73846154 0.70769231 0.6969697  0.75       0.72580645]
# moy_precision: 0.72
# sensibilité : [0.92307692 0.92       0.95833333 0.87272727 0.9       ]
# moy_sensibilité: 0.91
# spécificité : [0.15       0.13636364 0.16666667 0.05882353 0.22727273]
# moy_spécificité: 0.15
# MCC : [ 0.11048192  0.08763743  0.21320072 -0.09249946  0.16952582]
# MCC: 0.10
# GaussianNB
# Accuracy: [0.5        0.625      0.55555556 0.375      0.54166667]
# moy_accuracy: 0.52
# precision: [0.86363636 0.82857143 0.80769231 0.75       0.84      ]
# moy_precision: 0.82
# sensibilité : [0.36538462 0.58       0.4375     0.27272727 0.42      ]
# moy_sensibilité: 0.42
# spécificité : [0.85       0.72727273 0.79166667 0.70588235 0.81818182]
# moy_spécificité: 0.78
# MCC : [ 0.20942813  0.28319493  0.22491173 -0.02028185  0.23045494]
# MCC: 0.19
# KNeighborsClassifier
# Accuracy: [0.65277778 0.70833333 0.73611111 0.68055556 0.68055556]
# moy_accuracy: 0.69
# precision: [0.76470588 0.85365854 0.85365854 0.83333333 0.78723404]
# moy_precision: 0.82
# sensibilité : [0.75       0.7        0.72916667 0.72727273 0.74      ]
# moy_sensibilité: 0.73
# spécificité : [0.4        0.72727273 0.75       0.52941176 0.54545455]
# moy_spécificité: 0.59
# MCC : [0.14781319 0.39749232 0.45618401 0.23124865 0.27619408]
# MCC: 0.30

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=0.41,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    # evaluate model
    scores1 = cross_val_score(clf, X4, y4, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.72
# LogisticRegression
# accuracy: 0.64
# RandomForestClassifier
# accuracy: 0.75
# GradientBoostingClassifier
# accuracy: 0.74
# GaussianNB
# accuracy: 0.49
# KNeighborsClassifier
# accuracy: 0.68

# %% [markdown]
# **rééchantillonnage**

# %% [markdown]
# *Smote*

# %%
X4_1=X4.values

# %%
X4_1
# Out:
# array([[-1.59114200e+01,  2.37947400e+01,  0.00000000e+00, ...,
#          5.40000010e+00,  5.50000000e+00,  4.90000010e+00],
#        [-1.31883700e+01,  2.71329500e+01,  2.14420957e-04, ...,
#          4.30000019e+00,  3.70000005e+00,  3.79999995e+00],
#        [-1.31883700e+01,  2.71329500e+01,  2.14420957e-04, ...,
#          4.30000019e+00,  3.70000005e+00,  3.79999995e+00],
#        ...,
#        [-5.36086400e+00,  3.58017330e+01,  7.09788418e+00, ...,
#          4.00000000e+00,  3.90000010e+00,  3.79999995e+00],
#        [-5.36666700e+00,  3.58333330e+01,  7.41197777e+00, ...,
#          4.00000000e+00,  3.90000010e+00,  4.30000019e+00],
#        [-5.48333300e+00,  3.59000000e+01,  6.83951378e+00, ...,
#          4.00000000e+00,  4.00000000e+00,  4.19999981e+00]])

# %%
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.pipeline import Pipeline
def tp(y_true, y_pred): 
    error= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
    return error

my_scorer = make_scorer(tp, greater_is_better=True)
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=0.41,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    steps = [('over', BorderlineSMOTE()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    print(name)
    scores = cross_val_score(pipeline, X4_1, y4, scoring="accuracy", cv=cv, n_jobs=-1)
    scores1 = cross_val_score(pipeline, X4_1, y4, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(pipeline, X4_1, y4, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(pipeline, X4_1, y4, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4= cross_val_score(pipeline, X4_1, y4, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores5 = cross_val_score(pipeline, X4_1, y4, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.3f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.3f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.3f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.3f' % mean(scores3))
    print(' ROC AUC: ' , scores4)
    print('Mean ROC AUC: %.2f' % mean(scores4))
    print('MCC :',scores5)
    print('MCC: %.2f' % mean(scores5))
# Out:
# XGBClassifier
# Accuracy: [0.73611111 0.63888889 0.70833333 0.66666667 0.73611111]
# moy_accuracy: 0.697
# precision: [0.82222222 0.75555556 0.78       0.84782609 0.86046512]
# moy_precision: 0.813
# sensibilité : [0.71153846 0.68       0.72916667 0.72727273 0.78      ]
# moy_sensibilité: 0.726
# spécificité : [0.6        0.45454545 0.54166667 0.64705882 0.63636364]
# moy_spécificité: 0.576
#  ROC AUC:  [0.71826923 0.66545455 0.69053819 0.73048128 0.74090909]
# Mean ROC AUC: 0.71
# MCC : [0.32928032 0.3703693  0.34247476 0.21022619 0.48266935]
# MCC: 0.35
# LogisticRegression
# Accuracy: [0.59722222 0.56944444 0.65277778 0.58333333 0.58333333]
# moy_accuracy: 0.597
# precision: [0.76190476 0.71875    0.71428571 0.80487805 0.82926829]
# moy_precision: 0.766
# sensibilité : [0.51923077 0.44       0.6875     0.6        0.62      ]
# moy_sensibilité: 0.573
# spécificité : [0.5        0.68181818 0.625      0.47058824 0.59090909]
# moy_spécificité: 0.574
#  ROC AUC:  [0.5875     0.63545455 0.65234375 0.54973262 0.67545455]
# Mean ROC AUC: 0.62
# MCC : [0.16772557 0.10221829 0.25544268 0.07930931 0.33952521]
# MCC: 0.19
# RandomForestClassifier
# Accuracy: [0.70833333 0.66666667 0.69444444 0.61111111 0.73611111]
# moy_accuracy: 0.683
# precision: [0.82978723 0.73913043 0.77083333 0.86956522 0.84090909]
# moy_precision: 0.810
# sensibilité : [0.73076923 0.74       0.79166667 0.67272727 0.8       ]
# moy_sensibilité: 0.747
# spécificité : [0.55       0.5        0.54166667 0.52941176 0.63636364]
# moy_spécificité: 0.551
#  ROC AUC:  [0.73461538 0.74181818 0.72786458 0.69518717 0.77909091]
# Mean ROC AUC: 0.74
# MCC : [0.32928032 0.28       0.36514837 0.23124865 0.41854651]
# MCC: 0.32
# GradientBoostingClassifier
# Accuracy: [0.70833333 0.75       0.72222222 0.72222222 0.73611111]
# moy_accuracy: 0.728
# precision: [0.77358491 0.77586207 0.75925926 0.8        0.84      ]
# moy_precision: 0.790
# sensibilité : [0.76923077 0.88       0.875      0.76363636 0.8       ]
# moy_sensibilité: 0.818
# spécificité : [0.45       0.45454545 0.45833333 0.47058824 0.59090909]
# moy_spécificité: 0.485
#  ROC AUC:  [0.78942308 0.68272727 0.75130208 0.71550802 0.74636364]
# Mean ROC AUC: 0.74
# MCC : [0.21483446 0.38297084 0.33071891 0.29079869 0.40285634]
# MCC: 0.32
# GaussianNB
# Accuracy: [0.51388889 0.55555556 0.56944444 0.44444444 0.52777778]
# moy_accuracy: 0.522
# precision: [0.85       0.88461538 0.80769231 0.70833333 0.77777778]
# moy_precision: 0.806
# sensibilité : [0.36538462 0.48       0.41666667 0.36363636 0.44      ]
# moy_sensibilité: 0.413
# spécificité : [0.9        0.86363636 0.83333333 0.64705882 0.77272727]
# moy_spécificité: 0.803
#  ROC AUC:  [0.54375    0.665      0.63671875 0.45240642 0.61090909]
# Mean ROC AUC: 0.58
# MCC : [ 0.23061131  0.33321696  0.20628425 -0.05863005  0.18483062]
# MCC: 0.18
# KNeighborsClassifier
# Accuracy: [0.55555556 0.63888889 0.63888889 0.56944444 0.61111111]
# moy_accuracy: 0.603
# precision: [0.82857143 0.92       0.87096774 0.87878788 0.81818182]
# moy_precision: 0.863
# sensibilité : [0.5        0.5        0.52083333 0.52727273 0.54      ]
# moy_sensibilité: 0.518
# spécificité : [0.7        0.86363636 0.79166667 0.76470588 0.68181818]
# moy_spécificité: 0.760
#  ROC AUC:  [0.7        0.70636364 0.73958333 0.62032086 0.66909091]
# Mean ROC AUC: 0.69
# MCC : [0.20965697 0.35711719 0.32232919 0.21356357 0.21143208]
# MCC: 0.26

# %%
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.pipeline import Pipeline
from sklearn.svm import SVC
def tp(y_true, y_pred): 
    error= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
    return error

my_scorer = make_scorer(tp, greater_is_better=True)
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=0.41,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    steps = [('over', SMOTE()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    print(name)
    scores = cross_val_score(pipeline, X4_1, y4, scoring="accuracy", cv=cv, n_jobs=-1)
    scores1 = cross_val_score(pipeline, X4_1, y4, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(pipeline, X4_1, y4, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(pipeline, X4_1, y4, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4= cross_val_score(pipeline, X4_1, y4, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores5 = cross_val_score(pipeline, X4_1, y4, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print(' ROC AUC: ' , scores4)
    print('Mean ROC AUC: %.2f' % mean(scores4))
    print('MCC :',scores5)
    print('MCC: %.2f' % mean(scores5))
# Out:
# XGBClassifier
# Accuracy: [0.68055556 0.625      0.65277778 0.69444444 0.75      ]
# moy_accuracy: 0.68
# precision: [0.82978723 0.77083333 0.79545455 0.83333333 0.82978723]
# moy_precision: 0.81
# sensibilité : [0.73076923 0.74       0.66666667 0.70909091 0.76      ]
# moy_sensibilité: 0.72
# spécificité : [0.55       0.63636364 0.54166667 0.64705882 0.68181818]
# moy_spécificité: 0.61
#  ROC AUC:  [0.71346154 0.67454545 0.69487847 0.69839572 0.76818182]
# Mean ROC AUC: 0.71
# MCC : [0.39641752 0.2958296  0.32714433 0.24487619 0.49036165]
# MCC: 0.35
# LogisticRegression
# Accuracy: [0.58333333 0.55555556 0.63888889 0.56944444 0.625     ]
# moy_accuracy: 0.59
# precision: [0.77777778 0.75       0.79069767 0.8        0.77083333]
# moy_precision: 0.78
# sensibilité : [0.67307692 0.46       0.625      0.63636364 0.68      ]
# moy_sensibilité: 0.61
# spécificité : [0.55       0.59090909 0.625      0.41176471 0.68181818]
# moy_spécificité: 0.57
#  ROC AUC:  [0.61057692 0.64636364 0.66102431 0.55614973 0.67545455]
# Mean ROC AUC: 0.63
# MCC : [0.18615983 0.13483997 0.12171612 0.10977209 0.25619595]
# MCC: 0.16
# RandomForestClassifier
# Accuracy: [0.68055556 0.68055556 0.69444444 0.66666667 0.77777778]
# moy_accuracy: 0.70
# precision: [0.80434783 0.79166667 0.78       0.82978723 0.82608696]
# moy_precision: 0.81
# sensibilité : [0.71153846 0.8        0.83333333 0.72727273 0.8       ]
# moy_sensibilité: 0.77
# spécificité : [0.5        0.5        0.54166667 0.41176471 0.77272727]
# moy_spécificité: 0.55
#  ROC AUC:  [0.75769231 0.71090909 0.72092014 0.64919786 0.78454545]
# Mean ROC AUC: 0.72
# MCC : [0.26414795 0.31735069 0.41660256 0.23124865 0.50566869]
# MCC: 0.35
# GradientBoostingClassifier
# Accuracy: [0.69444444 0.76388889 0.69444444 0.70833333 0.77777778]
# moy_accuracy: 0.73
# precision: [0.79245283 0.8        0.76470588 0.84       0.81632653]
# moy_precision: 0.80
# sensibilité : [0.78846154 0.84       0.79166667 0.76363636 0.82      ]
# moy_sensibilité: 0.80
# spécificité : [0.45       0.45454545 0.45833333 0.58823529 0.5       ]
# moy_spécificité: 0.49
#  ROC AUC:  [0.7875     0.67454545 0.71397569 0.67914439 0.76545455]
# Mean ROC AUC: 0.72
# MCC : [0.28504386 0.40214735 0.42640143 0.11233264 0.42640143]
# MCC: 0.33
# GaussianNB
# Accuracy: [0.51388889 0.55555556 0.58333333 0.38888889 0.48611111]
# moy_accuracy: 0.51
# precision: [0.82608696 0.88888889 0.82142857 0.73076923 0.84      ]
# moy_precision: 0.82
# sensibilité : [0.32692308 0.5        0.4375     0.36363636 0.46      ]
# moy_sensibilité: 0.42
# spécificité : [0.9        0.86363636 0.79166667 0.64705882 0.81818182]
# moy_spécificité: 0.80
#  ROC AUC:  [0.6375     0.70772727 0.61414931 0.4144385  0.64590909]
# Mean ROC AUC: 0.60
# MCC : [0.14211194 0.26506933 0.22026448 0.02533202 0.27716093]
# MCC: 0.19
# KNeighborsClassifier
# Accuracy: [0.59722222 0.61111111 0.61111111 0.56944444 0.63888889]
# moy_accuracy: 0.61
# precision: [0.87096774 0.89285714 0.88888889 0.86111111 0.80555556]
# moy_precision: 0.86
# sensibilité : [0.5        0.56       0.5        0.56363636 0.56      ]
# moy_sensibilité: 0.54
# spécificité : [0.85       0.90909091 0.83333333 0.76470588 0.72727273]
# moy_spécificité: 0.82
#  ROC AUC:  [0.6875     0.70227273 0.69661458 0.6486631  0.68227273]
# Mean ROC AUC: 0.68
# MCC : [0.19707381 0.42179107 0.34040874 0.24886715 0.22286938]
# MCC: 0.29

# %%
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.pipeline import Pipeline
from sklearn.svm import SVC
def tp(y_true, y_pred): 
    error= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
    return error

my_scorer = make_scorer(tp, greater_is_better=True)
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=0.41,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    steps = [('over', ADASYN()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    print(name)
    scores = cross_val_score(pipeline, X4_1, y4, scoring="accuracy", cv=cv, n_jobs=-1)
    scores1 = cross_val_score(pipeline, X4_1, y4, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(pipeline, X4_1, y4, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(pipeline, X4_1, y4, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4= cross_val_score(pipeline, X4_1, y4, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores5 = cross_val_score(pipeline, X4_1, y4, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print(' ROC AUC: ' , scores4)
    print('Mean ROC AUC: %.2f' % mean(scores4))
    print('MCC :',scores5)
    print('MCC: %.2f' % mean(scores5))
# Out:
# XGBClassifier
# Accuracy: [0.69444444 0.625      0.68055556 0.68055556 0.73611111]
# moy_accuracy: 0.68
# precision: [0.84090909 0.75555556 0.77083333 0.82608696 0.84444444]
# moy_precision: 0.81
# sensibilité : [0.75       0.72       0.70833333 0.69090909 0.78      ]
# moy_sensibilité: 0.73
# spécificité : [0.65       0.5        0.54166667 0.70588235 0.68181818]
# moy_spécificité: 0.62
#  ROC AUC:  [0.73076923 0.65727273 0.69401042 0.73475936 0.76454545]
# Mean ROC AUC: 0.72
# MCC : [0.32910134 0.23452079 0.29880715 0.2628896  0.42038943]
# MCC: 0.31
# LogisticRegression
# Accuracy: [0.625      0.52777778 0.68055556 0.56944444 0.625     ]
# moy_accuracy: 0.61
# precision: [0.8        0.74358974 0.80555556 0.79487179 0.78947368]
# moy_precision: 0.79
# sensibilité : [0.67307692 0.44       0.60416667 0.61818182 0.56      ]
# moy_sensibilité: 0.58
# spécificité : [0.6        0.59090909 0.75       0.41176471 0.59090909]
# moy_spécificité: 0.59
#  ROC AUC:  [0.56923077 0.62363636 0.64539931 0.55187166 0.66181818]
# Mean ROC AUC: 0.61
# MCC : [0.23856303 0.15769948 0.21639461 0.0292509  0.29559537]
# MCC: 0.19
# RandomForestClassifier
# Accuracy: [0.63888889 0.66666667 0.69444444 0.68055556 0.73611111]
# moy_accuracy: 0.68
# precision: [0.85106383 0.77358491 0.78       0.82       0.86046512]
# moy_precision: 0.82
# sensibilité : [0.71153846 0.8        0.79166667 0.72727273 0.76      ]
# moy_sensibilité: 0.76
# spécificité : [0.7        0.5        0.5        0.58823529 0.77272727]
# moy_spécificité: 0.61
#  ROC AUC:  [0.76153846 0.68181818 0.73133681 0.65668449 0.77363636]
# Mean ROC AUC: 0.72
# MCC : [0.19901558 0.19180536 0.37880804 0.18022041 0.54022602]
# MCC: 0.30
# GradientBoostingClassifier
# Accuracy: [0.72222222 0.69444444 0.73611111 0.69444444 0.76388889]
# moy_accuracy: 0.72
# precision: [0.82       0.77777778 0.71929825 0.80769231 0.82      ]
# moy_precision: 0.79
# sensibilité : [0.75       0.86       0.83333333 0.72727273 0.8       ]
# moy_sensibilité: 0.79
# spécificité : [0.45       0.5        0.54166667 0.47058824 0.63636364]
# moy_spécificité: 0.52
#  ROC AUC:  [0.77403846 0.68       0.74175347 0.66096257 0.74636364]
# Mean ROC AUC: 0.72
# MCC : [0.42069908 0.34117245 0.35082321 0.25036024 0.42640143]
# MCC: 0.36
# GaussianNB
# Accuracy: [0.51388889 0.55555556 0.54166667 0.38888889 0.54166667]
# moy_accuracy: 0.51
# precision: [0.89473684 0.86956522 0.81481481 0.77272727 0.80769231]
# moy_precision: 0.83
# sensibilité : [0.36538462 0.48       0.4375     0.29090909 0.4       ]
# moy_sensibilité: 0.39
# spécificité : [0.9        0.81818182 0.79166667 0.58823529 0.77272727]
# moy_spécificité: 0.77
#  ROC AUC:  [0.70769231 0.68363636 0.63324653 0.43957219 0.64727273]
# Mean ROC AUC: 0.62
# MCC : [0.23061131 0.2604592  0.22491173 0.01380467 0.18483062]
# MCC: 0.18
# KNeighborsClassifier
# Accuracy: [0.56944444 0.59722222 0.59722222 0.58333333 0.625     ]
# moy_accuracy: 0.59
# precision: [0.86206897 0.95833333 0.85714286 0.90625    0.82352941]
# moy_precision: 0.88
# sensibilité : [0.48076923 0.48       0.47916667 0.52727273 0.56      ]
# moy_sensibilité: 0.51
# spécificité : [0.85       0.90909091 0.875      0.64705882 0.68181818]
# moy_spécificité: 0.79
#  ROC AUC:  [0.75769231 0.73954545 0.71918403 0.64010695 0.66636364]
# Mean ROC AUC: 0.70
# MCC : [0.17668837 0.40508136 0.25       0.11759656 0.26506933]
# MCC: 0.24

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=0.41,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    steps = [('over', SMOTE()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    # evaluate model
    scores1 = cross_val_score(pipeline, X4_1, y4, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.68
# LogisticRegression
# accuracy: 0.62
# RandomForestClassifier
# accuracy: 0.70
# GradientBoostingClassifier
# accuracy: 0.73
# GaussianNB
# accuracy: 0.51
# KNeighborsClassifier
# accuracy: 0.61

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=0.41,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    steps = [('over', ADASYN()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    # evaluate model
    scores1 = cross_val_score(pipeline, X4_1, y4, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.67
# LogisticRegression
# accuracy: 0.63
# RandomForestClassifier
# accuracy: 0.70
# GradientBoostingClassifier
# accuracy: 0.73
# GaussianNB
# accuracy: 0.51
# KNeighborsClassifier
# accuracy: 0.57

# %% [markdown]
# # cx_pipie _xgb

# %%
Clc2 = '/content/Classeura1.xlsx'
datac2= pd.read_excel(Clc2,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True)

# %%
selected_feat_xgb2 = ['Var_IRM', 'Amp2_TempN', 'VarT_ann_EVI', 'Bio_Saison', 'Bio_Tch_Moy',
       'Prec_Juill', 'Prec_Aout', 'Tmax_Fev', 'Tmax_Mai', 'Tmax_Nov',
       'Vent_Avril', 'Vent_Aout']

# %%
X5 = datac2.loc[:, datac2.columns != 'Cx_pipiens']
y5 = datac2.Cx_pipiens

# %%
X5=X5[selected_feat_xgb2]

# %%
X5
# Out:
#      Var_IRM  Amp2_TempN  VarT_ann_EVI  ...   Tmax_Nov  Vent_Avril  Vent_Aout
# 0          0          44             1  ...  24.500000         6.9        7.2
# 1          0          55            12  ...  25.100000         5.6        5.9
# 2          0          55            12  ...  25.100000         5.6        5.9
# 3          0          61             7  ...  25.100000         5.6        6.2
# 4         10          58             1  ...  25.299999         5.2        5.8
# ..       ...         ...           ...  ...        ...         ...        ...
# 355        0          35            47  ...  19.400000         3.9        3.3
# 356        0          40            65  ...  18.700001         4.3        4.1
# 357        0          34            53  ...  19.100000         4.2        4.0
# 358        0          27            79  ...  18.700001         4.3        4.0
# 359        0          19            45  ...  19.000000         4.4        3.7
#
# [360 rows x 12 columns]

# %%
y5
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 355    1
# 356    1
# 357    1
# 358    1
# 359    1
# Name: Cx_pipiens, Length: 360, dtype: int64

# %%
from sklearn.metrics import matthews_corrcoef
classifiers = {
    "XGBClassifier":  XGBClassifier(scale_pos_weight=0.41,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(learning_rate=0.1, n_estimators=10, random_state=11),
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
def tp(y_true, y_pred): 
    error= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
    return error

my_scorer = make_scorer(tp, greater_is_better=True)
def tp1(y_true, y_pred): 
    MCC= matthews_corrcoef(y_true, y_pred)
    return MCC

my_scorer1 = make_scorer(tp1, greater_is_better=True)
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    fig, ax = plt.subplots(figsize=(11, 5))
    for i, (train, test) in enumerate(cv.split(X5, y5)):
         clf.fit(X5.loc[train,], y5.loc[train,])
         viz = plot_roc_curve(clf, X5.loc[test,], y5.loc[test,],
                         name='ROC fold {}'.format(i),
                         alpha=0.3, lw=1, ax=ax)
         interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
         interp_tpr[0] = 0.0
         tprs.append(interp_tpr)
         aucs.append(viz.roc_auc)

    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=2, alpha=.8)

    ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="courbe roc %s " %name)
    ax.legend(loc="lower right")
    plt.show()
    # evaluate model
    scores = cross_val_score(clf, X5, y5, scoring='accuracy', cv=cv, n_jobs=-1)
    scores1 = cross_val_score(clf, X5, y5, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf, X5, y5, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X5, y5, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X5, y5, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
# Out:
# XGBClassifier
# Accuracy: [0.66666667 0.66666667 0.76388889 0.70833333 0.77777778]
# moy_accuracy: 0.72
# precision: [0.86842105 0.7826087  0.81632653 0.85416667 0.85416667]
# moy_precision: 0.84
# sensibilité : [0.63461538 0.72       0.83333333 0.74545455 0.82      ]
# moy_sensibilité: 0.75
# spécificité : [0.75       0.54545455 0.625      0.58823529 0.68181818]
# moy_spécificité: 0.64
# MCC : [0.34507386 0.25457803 0.46338901 0.30062324 0.49036165]
# MCC: 0.37
# LogisticRegression
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Accuracy: [0.59722222 0.63888889 0.69444444 0.43055556 0.69444444]
# moy_accuracy: 0.61
# precision: [0.79487179 0.875      0.7826087  0.70588235 0.91176471]
# moy_precision: 0.81
# sensibilité : [0.59615385 0.56       0.75       0.43636364 0.62      ]
# moy_sensibilité: 0.59
# spécificité : [0.6        0.81818182 0.58333333 0.41176471 0.86363636]
# moy_spécificité: 0.66
# MCC : [ 0.17632919  0.35058393  0.32714433 -0.12919666  0.44625596]
# MCC: 0.23
# RandomForestClassifier
# Accuracy: [0.77777778 0.69444444 0.75       0.75       0.72222222]
# moy_accuracy: 0.74
# precision: [0.79032258 0.71875    0.75862069 0.79365079 0.75      ]
# moy_precision: 0.76
# sensibilité : [0.94230769 0.92       0.91666667 0.90909091 0.9       ]
# moy_sensibilité: 0.92
# spécificité : [0.35       0.18181818 0.41666667 0.23529412 0.31818182]
# moy_spécificité: 0.30
# MCC : [0.37858297 0.1492405  0.39703333 0.1854114  0.26967994]
# MCC: 0.28
# GradientBoostingClassifier
# Accuracy: [0.69444444 0.66666667 0.73611111 0.76388889 0.69444444]
# moy_accuracy: 0.71
# precision: [0.734375   0.69117647 0.73015873 0.77941176 0.71875   ]
# moy_precision: 0.73
# sensibilité : [0.90384615 0.94       0.95833333 0.96363636 0.92      ]
# moy_sensibilité: 0.94
# spécificité : [0.15       0.04545455 0.29166667 0.11764706 0.18181818]
# moy_spécificité: 0.16
# MCC : [ 0.07674258 -0.0292509   0.35634832  0.1507035   0.1492405 ]
# MCC: 0.14
# GaussianNB
# Accuracy: [0.65277778 0.63888889 0.66666667 0.55555556 0.69444444]
# moy_accuracy: 0.64
# precision: [0.8        0.73076923 0.69354839 0.74468085 0.75925926]
# moy_precision: 0.75
# sensibilité : [0.69230769 0.76       0.89583333 0.63636364 0.82      ]
# moy_sensibilité: 0.76
# spécificité : [0.55       0.36363636 0.20833333 0.29411765 0.40909091]
# moy_spécificité: 0.37
# MCC : [ 0.22417942  0.12715279  0.14199046 -0.06201384  0.24370872]
# MCC: 0.14
# KNeighborsClassifier
# Accuracy: [0.63888889 0.59722222 0.69444444 0.66666667 0.66666667]
# moy_accuracy: 0.65
# precision: [0.825      0.74418605 0.74074074 0.80392157 0.77083333]
# moy_precision: 0.78
# sensibilité : [0.63461538 0.64       0.83333333 0.74545455 0.74      ]
# moy_sensibilité: 0.72
# spécificité : [0.65       0.5        0.41666667 0.41176471 0.5       ]
# moy_spécificité: 0.50
# MCC : [0.25654884 0.13148952 0.27216553 0.14689831 0.23452079]
# MCC: 0.21

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=0.41,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    # evaluate model
    scores1 = cross_val_score(clf, X5, y5, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.73
# LogisticRegression
# accuracy: 0.65
# RandomForestClassifier
# accuracy: 0.74
# GradientBoostingClassifier
# accuracy: 0.76
# GaussianNB
# accuracy: 0.62
# KNeighborsClassifier
# accuracy: 0.67

# %% [markdown]
# **rééchantillonnage**

# %%
X5_1=X5.values

# %%
X5
# Out:
#      Var_IRM  Amp2_TempN  VarT_ann_EVI  ...   Tmax_Nov  Vent_Avril  Vent_Aout
# 0          0          44             1  ...  24.500000         6.9        7.2
# 1          0          55            12  ...  25.100000         5.6        5.9
# 2          0          55            12  ...  25.100000         5.6        5.9
# 3          0          61             7  ...  25.100000         5.6        6.2
# 4         10          58             1  ...  25.299999         5.2        5.8
# ..       ...         ...           ...  ...        ...         ...        ...
# 355        0          35            47  ...  19.400000         3.9        3.3
# 356        0          40            65  ...  18.700001         4.3        4.1
# 357        0          34            53  ...  19.100000         4.2        4.0
# 358        0          27            79  ...  18.700001         4.3        4.0
# 359        0          19            45  ...  19.000000         4.4        3.7
#
# [360 rows x 12 columns]

# %%
y5
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 355    1
# 356    1
# 357    1
# 358    1
# 359    1
# Name: Cx_pipiens, Length: 360, dtype: int64

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1.5,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    steps = [('over', SMOTE()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    print(name)
    scores = cross_val_score(pipeline, X5_1, y5, scoring="accuracy", cv=cv, n_jobs=-1)
    scores1 = cross_val_score(pipeline, X5_1, y5, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(pipeline, X5_1, y5, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(pipeline, X5_1, y5, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4= cross_val_score(pipeline, X5_1, y5, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores5 = cross_val_score(pipeline, X5_1, y5, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print(' ROC AUC: ' , scores4)
    print('Mean ROC AUC: %.2f' % mean(scores4))
    print('MCC :',scores5)
    print('MCC: %.2f' % mean(scores5))
# Out:
# XGBClassifier
# Accuracy: [0.77777778 0.70833333 0.69444444 0.77777778 0.73611111]
# moy_accuracy: 0.74
# precision: [0.875      0.74137931 0.76363636 0.7962963  0.80769231]
# moy_precision: 0.80
# sensibilité : [0.82692308 0.82       0.83333333 0.83636364 0.82      ]
# moy_sensibilité: 0.83
# spécificité : [0.65       0.36363636 0.54166667 0.58823529 0.59090909]
# moy_spécificité: 0.55
#  ROC AUC:  [0.81346154 0.64818182 0.78081597 0.72513369 0.73818182]
# Mean ROC AUC: 0.74
# MCC : [0.52467744 0.17941959 0.40824829 0.40913814 0.42640143]
# MCC: 0.39
# LogisticRegression
# Accuracy: [0.55555556 0.63888889 0.66666667 0.52777778 0.63888889]
# moy_accuracy: 0.61
# precision: [0.825      0.84848485 0.78723404 0.76923077 0.88888889]
# moy_precision: 0.82
# sensibilité : [0.63461538 0.6        0.72916667 0.45454545 0.62      ]
# moy_sensibilité: 0.61
# spécificité : [0.55       0.68181818 0.625      0.47058824 0.77272727]
# moy_spécificité: 0.62
#  ROC AUC:  [0.67019231 0.60818182 0.76258681 0.52620321 0.70272727]
# Mean ROC AUC: 0.65
# MCC : [ 0.09662068  0.34352048  0.36514837 -0.10237814  0.42863197]
# MCC: 0.23
# RandomForestClassifier
# Accuracy: [0.69444444 0.72222222 0.75       0.68055556 0.72222222]
# moy_accuracy: 0.71
# precision: [0.84782609 0.77083333 0.80487805 0.86363636 0.82608696]
# moy_precision: 0.82
# sensibilité : [0.61538462 0.78       0.72916667 0.69090909 0.74      ]
# moy_sensibilité: 0.71
# spécificité : [0.75       0.59090909 0.625      0.64705882 0.59090909]
# moy_spécificité: 0.64
#  ROC AUC:  [0.75096154 0.78       0.76866319 0.70374332 0.74272727]
# Mean ROC AUC: 0.75
# MCC : [0.38135638 0.17126977 0.29880715 0.30913724 0.36244122]
# MCC: 0.30
# GradientBoostingClassifier
# Accuracy: [0.72222222 0.68055556 0.76388889 0.73611111 0.76388889]
# moy_accuracy: 0.73
# precision: [0.88888889 0.76470588 0.8        0.85714286 0.85106383]
# moy_precision: 0.83
# sensibilité : [0.69230769 0.72       0.79166667 0.74545455 0.8       ]
# moy_sensibilité: 0.75
# spécificité : [0.7        0.54545455 0.54166667 0.64705882 0.63636364]
# moy_spécificité: 0.61
#  ROC AUC:  [0.80096154 0.67909091 0.79991319 0.77326203 0.76090909]
# Mean ROC AUC: 0.76
# MCC : [0.41931393 0.27619408 0.45374261 0.39063991 0.45086385]
# MCC: 0.40
# GaussianNB
# Accuracy: [0.5        0.625      0.63888889 0.43055556 0.54166667]
# moy_accuracy: 0.55
# precision: [0.89473684 0.74285714 0.76470588 0.7        0.82608696]
# moy_precision: 0.79
# sensibilité : [0.42307692 0.58       0.52083333 0.56363636 0.36      ]
# moy_sensibilité: 0.49
# spécificité : [0.85       0.68181818 0.66666667 0.23529412 0.72727273]
# moy_spécificité: 0.63
#  ROC AUC:  [0.61826923 0.61818182 0.60199653 0.46631016 0.69727273]
# Mean ROC AUC: 0.60
# MCC : [ 0.19876211  0.30151134 -0.02062842 -0.1381975   0.2199066 ]
# MCC: 0.11
# KNeighborsClassifier
# Accuracy: [0.5        0.52777778 0.66666667 0.58333333 0.58333333]
# moy_accuracy: 0.57
# precision: [0.8        0.79310345 0.8        0.8        0.82857143]
# moy_precision: 0.80
# sensibilité : [0.40384615 0.36       0.625      0.56363636 0.6       ]
# moy_sensibilité: 0.51
# spécificité : [0.75       0.72727273 0.70833333 0.58823529 0.77272727]
# moy_spécificité: 0.71
#  ROC AUC:  [0.62019231 0.61272727 0.65711806 0.64438503 0.67681818]
# Mean ROC AUC: 0.64
# MCC : [0.01434623 0.14012981 0.27509212 0.09811049 0.28990594]
# MCC: 0.16

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1.4,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    steps = [('over', SMOTE()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    # evaluate model
    scores1 = cross_val_score(pipeline, X5_1, y5, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.75
# LogisticRegression
# accuracy: 0.59
# RandomForestClassifier
# accuracy: 0.69
# GradientBoostingClassifier
# accuracy: 0.73
# GaussianNB
# accuracy: 0.55
# KNeighborsClassifier
# accuracy: 0.59

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1.4,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    steps = [('over', ADASYN()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    print(name)
    scores = cross_val_score(pipeline, X5_1, y5, scoring="accuracy", cv=cv, n_jobs=-1)
    scores1 = cross_val_score(pipeline, X5_1, y5, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(pipeline, X5_1, y5, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(pipeline, X5_1, y5, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4= cross_val_score(pipeline, X5_1, y5, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores5 = cross_val_score(pipeline, X5_1, y5, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print(' ROC AUC: ' , scores4)
    print('Mean ROC AUC: %.2f' % mean(scores4))
    print('MCC :',scores5)
    print('MCC: %.2f' % mean(scores5))
# Out:
# XGBClassifier
# Accuracy: [0.73611111 0.65277778 0.72222222 0.77777778 0.79166667]
# moy_accuracy: 0.74
# precision: [0.81395349 0.72727273 0.77777778 0.88       0.78846154]
# moy_precision: 0.80
# sensibilité : [0.76923077 0.82       0.83333333 0.81818182 0.82      ]
# moy_sensibilité: 0.81
# spécificité : [0.6        0.36363636 0.5        0.70588235 0.63636364]
# moy_spécificité: 0.56
#  ROC AUC:  [0.8125     0.75454545 0.79383681 0.76684492 0.73909091]
# Mean ROC AUC: 0.77
# MCC : [0.3944127  0.0805823  0.42640143 0.38535511 0.51552958]
# MCC: 0.36
# LogisticRegression
# Accuracy: [0.625      0.61111111 0.72222222 0.44444444 0.66666667]
# moy_accuracy: 0.61
# precision: [0.78378378 0.87096774 0.78571429 0.72222222 0.87878788]
# moy_precision: 0.81
# sensibilité : [0.59615385 0.54       0.75       0.47272727 0.58      ]
# moy_sensibilité: 0.59
# spécificité : [0.5        0.68181818 0.41666667 0.41176471 0.77272727]
# moy_spécificité: 0.56
#  ROC AUC:  [0.70769231 0.59090909 0.76085069 0.51122995 0.71181818]
# Mean ROC AUC: 0.66
# MCC : [ 0.19414507  0.24709372  0.20446521 -0.0327035   0.30760647]
# MCC: 0.18
# RandomForestClassifier
# Accuracy: [0.69444444 0.69444444 0.72222222 0.65277778 0.72222222]
# moy_accuracy: 0.70
# precision: [0.89473684 0.82       0.79166667 0.92307692 0.8       ]
# moy_precision: 0.85
# sensibilité : [0.65384615 0.78       0.72916667 0.69090909 0.72      ]
# moy_sensibilité: 0.71
# spécificité : [0.7        0.45454545 0.66666667 0.82352941 0.63636364]
# moy_spécificité: 0.66
#  ROC AUC:  [0.79903846 0.76636364 0.77994792 0.70481283 0.73727273]
# Mean ROC AUC: 0.76
# MCC : [0.43412157 0.34545455 0.38848389 0.27621518 0.38619812]
# MCC: 0.37
# GradientBoostingClassifier
# Accuracy: [0.72222222 0.63888889 0.70833333 0.73611111 0.73611111]
# moy_accuracy: 0.71
# precision: [0.88095238 0.76470588 0.8        0.87755102 0.83673469]
# moy_precision: 0.83
# sensibilité : [0.69230769 0.76       0.79166667 0.78181818 0.8       ]
# moy_sensibilité: 0.77
# spécificité : [0.7        0.40909091 0.625      0.64705882 0.63636364]
# moy_spécificité: 0.60
#  ROC AUC:  [0.81826923 0.65454545 0.80685764 0.77754011 0.74454545]
# Mean ROC AUC: 0.76
# MCC : [0.33217414 0.19446897 0.375      0.32050007 0.42640143]
# MCC: 0.33
# GaussianNB
# Accuracy: [0.47222222 0.52777778 0.54166667 0.38888889 0.5       ]
# moy_accuracy: 0.49
# precision: [0.90909091 0.73529412 0.7027027  0.6969697  0.83333333]
# moy_precision: 0.78
# sensibilité : [0.36538462 0.5        0.5        0.38181818 0.42      ]
# moy_sensibilité: 0.43
# spécificité : [0.9        0.59090909 0.625      0.41176471 0.81818182]
# moy_spécificité: 0.67
#  ROC AUC:  [0.73846154 0.58727273 0.60112847 0.42673797 0.67272727]
# Mean ROC AUC: 0.61
# MCC : [ 0.24615385  0.0838827   0.15811388 -0.16087993  0.12205796]
# MCC: 0.09
# KNeighborsClassifier
# Accuracy: [0.45833333 0.5        0.625      0.51388889 0.56944444]
# moy_accuracy: 0.53
# precision: [0.80769231 0.77777778 0.80487805 0.81081081 0.81818182]
# moy_precision: 0.80
# sensibilité : [0.34615385 0.34       0.58333333 0.54545455 0.56      ]
# moy_sensibilité: 0.47
# spécificité : [0.8        0.77272727 0.70833333 0.58823529 0.77272727]
# moy_spécificité: 0.73
#  ROC AUC:  [0.62451923 0.67454545 0.69010417 0.64759358 0.64181818]
# Mean ROC AUC: 0.66
# MCC : [0.12664628 0.20240973 0.21639461 0.11359764 0.24120908]
# MCC: 0.18

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1.4,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    steps = [('over', ADASYN()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    # evaluate model
    scores1 = cross_val_score(pipeline, X5_1, y5, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.76
# LogisticRegression
# accuracy: 0.60
# RandomForestClassifier
# accuracy: 0.70
# GradientBoostingClassifier
# accuracy: 0.72
# GaussianNB
# accuracy: 0.52
# KNeighborsClassifier
# accuracy: 0.57

# %% [markdown]
# # cx_pipiens _ régression

# %%
Clc3 = '/content/Classeura1.xlsx'
datac3= pd.read_excel(Clc3,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True)

# %%
selected_feat_cx_regr =["Pente_Min","IPT_Med","Amp3_TempJ","Equides","Min_EVI","Rad_Avril","Ph1_IRM","Amp2_TempN","Ph3_IRM","Elev_sd","Geom_Shan","Isoth","Vent_Sept","Vent_Nov","Var_IRM","ZoneAride","Pente_Moyenne","Coniferes","Ovins","Max_IRM","Var_TempN","CEC"]

# %%
X6 = datac3.loc[:, datac3.columns != 'Cx_pipiens']
y6 = datac3.Cx_pipiens

# %%
X6=X6[selected_feat_cx_regr]

# %%
X6
# Out:
#      Pente_Min  IPT_Med  Amp3_TempJ  ...  Max_IRM  Var_TempN        CEC
# 0     0.123749  -0.1875           7  ...     3950          3  11.166667
# 1     0.043752  -0.5000          31  ...     4660          9  12.750000
# 2     0.043752  -0.5000          31  ...     4660          9  12.750000
# 3     1.057192   1.5625          23  ...     4140          8  12.000000
# 4     0.333201  -3.7500          33  ...     3540          9  12.750000
# ..         ...      ...         ...  ...      ...        ...        ...
# 355   0.255113  -0.1875          14  ...     3120         24  21.083333
# 356   5.809525   1.3125           5  ...     1950         19  27.000000
# 357   0.061874  -0.8750           4  ...     2050         17  25.666667
# 358   2.375778   2.2500           6  ...     2430         17  19.666667
# 359   0.680587   0.3125           2  ...     1870         16  18.833333
#
# [360 rows x 22 columns]

# %%
y6
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 355    1
# 356    1
# 357    1
# 358    1
# 359    1
# Name: Cx_pipiens, Length: 360, dtype: int64

# %%
from sklearn.metrics import matthews_corrcoef
classifiers = {
    "XGBClassifier":  XGBClassifier(scale_pos_weight=0.41,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(learning_rate=0.1, n_estimators=10, random_state=11),
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
def tp(y_true, y_pred): 
    error= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
    return error

my_scorer = make_scorer(tp, greater_is_better=True)
def tp1(y_true, y_pred): 
    MCC= matthews_corrcoef(y_true, y_pred)
    return MCC

my_scorer1 = make_scorer(tp1, greater_is_better=True)
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    fig, ax = plt.subplots(figsize=(11, 5))
    for i, (train, test) in enumerate(cv.split(X6, y6)):
         clf.fit(X6.loc[train,], y6.loc[train,])
         viz = plot_roc_curve(clf, X6.loc[test,], y6.loc[test,],
                         name='ROC fold {}'.format(i),
                         alpha=0.3, lw=1, ax=ax)
         interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
         interp_tpr[0] = 0.0
         tprs.append(interp_tpr)
         aucs.append(viz.roc_auc)

    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=2, alpha=.8)

    ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="courbe roc %s " %name)
    ax.legend(loc="lower right")
    plt.show()
    # evaluate model
    scores = cross_val_score(clf, X6, y6, scoring='accuracy', cv=cv, n_jobs=-1)
    scores1 = cross_val_score(clf, X6, y6, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf, X6, y6, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X6, y6, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X6, y6, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
# Out:
# XGBClassifier
# Accuracy: [0.625      0.625      0.69444444 0.68055556 0.68055556]
# moy_accuracy: 0.66
# precision: [0.76595745 0.7254902  0.80952381 0.7962963  0.81395349]
# moy_precision: 0.78
# sensibilité : [0.69230769 0.74       0.70833333 0.78181818 0.7       ]
# moy_sensibilité: 0.72
# spécificité : [0.45       0.36363636 0.66666667 0.35294118 0.63636364]
# moy_spécificité: 0.49
# MCC : [0.13388321 0.1050301  0.35856858 0.13216961 0.31591639]
# MCC: 0.21
# LogisticRegression
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Accuracy: [0.59722222 0.61111111 0.61111111 0.52777778 0.58333333]
# moy_accuracy: 0.59
# precision: [0.82857143 0.75       0.79411765 0.76923077 0.79411765]
# moy_precision: 0.79
# sensibilité : [0.55769231 0.66       0.5625     0.54545455 0.54      ]
# moy_sensibilité: 0.57
# spécificité : [0.7        0.5        0.70833333 0.47058824 0.68181818]
# moy_spécificité: 0.61
# MCC : [0.23093153 0.15118579 0.25573908 0.01367402 0.20467379]
# MCC: 0.17
# RandomForestClassifier
# Accuracy: [0.76388889 0.72222222 0.68055556 0.76388889 0.79166667]
# moy_accuracy: 0.74
# precision: [0.75362319 0.72727273 0.6984127  0.77941176 0.77777778]
# moy_precision: 0.75
# sensibilité : [1.         0.96       0.91666667 0.96363636 0.98      ]
# moy_sensibilité: 0.96
# spécificité : [0.15       0.18181818 0.20833333 0.11764706 0.36363636]
# moy_spécificité: 0.20
# MCC : [0.33621939 0.23636364 0.17817416 0.1507035  0.47863442]
# MCC: 0.28
# GradientBoostingClassifier
# Accuracy: [0.73611111 0.63888889 0.625      0.70833333 0.69444444]
# moy_accuracy: 0.68
# precision: [0.73239437 0.67647059 0.66666667 0.75       0.70588235]
# moy_precision: 0.71
# sensibilité : [1.         0.92       0.875      0.92727273 0.96      ]
# moy_sensibilité: 0.94
# spécificité : [0.05       0.         0.125      0.         0.09090909]
# moy_spécificité: 0.05
# MCC : [ 0.19136279 -0.16087993  0.         -0.13483997  0.10237814]
# MCC: -0.00
# GaussianNB
# Accuracy: [0.68055556 0.61111111 0.55555556 0.55555556 0.61111111]
# moy_accuracy: 0.60
# precision: [0.80851064 0.75       0.67391304 0.82857143 0.78947368]
# moy_precision: 0.77
# sensibilité : [0.73076923 0.66       0.64583333 0.52727273 0.6       ]
# moy_sensibilité: 0.63
# spécificité : [0.55       0.5        0.375      0.64705882 0.63636364]
# moy_spécificité: 0.54
# MCC : [0.26414795 0.15118579 0.02044652 0.14813133 0.21809502]
# MCC: 0.16
# KNeighborsClassifier
# Accuracy: [0.68055556 0.68055556 0.72222222 0.625      0.73611111]
# moy_accuracy: 0.69
# precision: [0.77358491 0.8        0.83333333 0.80434783 0.81632653]
# moy_precision: 0.81
# sensibilité : [0.78846154 0.72       0.72916667 0.67272727 0.8       ]
# moy_sensibilité: 0.74
# spécificité : [0.4        0.59090909 0.70833333 0.47058824 0.59090909]
# moy_spécificité: 0.55
# MCC : [0.19152465 0.2958296  0.41833001 0.12671657 0.38619812]
# MCC: 0.28

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=0.41,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    # evaluate model
    scores1 = cross_val_score(clf, X6, y6, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.69
# LogisticRegression
# accuracy: 0.55
# RandomForestClassifier
# accuracy: 0.75
# GradientBoostingClassifier
# accuracy: 0.76
# GaussianNB
# accuracy: 0.63
# KNeighborsClassifier
# accuracy: 0.66

# %% [markdown]
# **rééchantillonnage**

# %% [markdown]
# # Smote :

# %%
X6_1=X6.values

# %%
X6_1
# Out:
# array([[ 1.23748794e-01, -1.87500000e-01,  7.00000000e+00, ...,
#          3.95000000e+03,  3.00000000e+00,  1.11666667e+01],
#        [ 4.37518656e-02, -5.00000000e-01,  3.10000000e+01, ...,
#          4.66000000e+03,  9.00000000e+00,  1.27500000e+01],
#        [ 4.37518656e-02, -5.00000000e-01,  3.10000000e+01, ...,
#          4.66000000e+03,  9.00000000e+00,  1.27500000e+01],
#        ...,
#        [ 6.18744679e-02, -8.75000000e-01,  4.00000000e+00, ...,
#          2.05000000e+03,  1.70000000e+01,  2.56666667e+01],
#        [ 2.37577772e+00,  2.25000000e+00,  6.00000000e+00, ...,
#          2.43000000e+03,  1.70000000e+01,  1.96666667e+01],
#        [ 6.80587411e-01,  3.12500000e-01,  2.00000000e+00, ...,
#          1.87000000e+03,  1.60000000e+01,  1.88333333e+01]])

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=0.45,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    steps = [('over', BorderlineSMOTE()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    print(name)
    scores = cross_val_score(pipeline, X6_1, y6, scoring="accuracy", cv=cv, n_jobs=-1)
    scores1 = cross_val_score(pipeline, X6_1, y6, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(pipeline, X6_1, y6, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(pipeline, X6_1, y6, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4= cross_val_score(pipeline, X6_1, y6, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores5 = cross_val_score(pipeline, X6_1, y6, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print(' ROC AUC: ' , scores4)
    print('Mean ROC AUC: %.2f' % mean(scores4))
    print('MCC :',scores5)
    print('MCC: %.2f' % mean(scores5))
# Out:
# XGBClassifier
# Accuracy: [0.63888889 0.63888889 0.72222222 0.69444444 0.61111111]
# moy_accuracy: 0.66
# precision: [0.81081081 0.75675676 0.80487805 0.82608696 0.84210526]
# moy_precision: 0.81
# sensibilité : [0.57692308 0.58       0.6875     0.70909091 0.64      ]
# moy_sensibilité: 0.64
# spécificité : [0.7        0.59090909 0.66666667 0.58823529 0.68181818]
# moy_spécificité: 0.65
#  ROC AUC:  [0.70576923 0.64272727 0.72873264 0.64064171 0.71545455]
# Mean ROC AUC: 0.69
# MCC : [0.25930764 0.13148952 0.31622777 0.2598113  0.31687394]
# MCC: 0.26
# LogisticRegression
# Accuracy: [0.56944444 0.61111111 0.59722222 0.56944444 0.63888889]
# moy_accuracy: 0.60
# precision: [0.71428571 0.7173913  0.75       0.81081081 0.75675676]
# moy_precision: 0.75
# sensibilité : [0.59615385 0.66       0.5625     0.6        0.6       ]
# moy_sensibilité: 0.60
# spécificité : [0.75       0.45454545 0.625      0.58823529 0.77272727]
# moy_spécificité: 0.64
#  ROC AUC:  [0.59519231 0.61727273 0.64019097 0.58823529 0.62090909]
# Mean ROC AUC: 0.61
# MCC : [0.1860521  0.23700827 0.1571955  0.14813133 0.22922795]
# MCC: 0.19
# RandomForestClassifier
# Accuracy: [0.69444444 0.61111111 0.70833333 0.625      0.66666667]
# moy_accuracy: 0.66
# precision: [0.88372093 0.8        0.76086957 0.82926829 0.825     ]
# moy_precision: 0.82
# sensibilité : [0.71153846 0.66       0.77083333 0.67272727 0.72      ]
# moy_sensibilité: 0.71
# spécificité : [0.75       0.54545455 0.58333333 0.52941176 0.68181818]
# moy_spécificité: 0.62
#  ROC AUC:  [0.77692308 0.64545455 0.75303819 0.63957219 0.74909091]
# Mean ROC AUC: 0.71
# MCC : [0.28296057 0.15118579 0.36514837 0.24309011 0.4179107 ]
# MCC: 0.29
# GradientBoostingClassifier
# Accuracy: [0.625      0.625      0.68055556 0.75       0.68055556]
# moy_accuracy: 0.67
# precision: [0.79591837 0.75       0.7755102  0.85416667 0.8372093 ]
# moy_precision: 0.80
# sensibilité : [0.78846154 0.7        0.72916667 0.78181818 0.72      ]
# moy_sensibilité: 0.74
# spécificité : [0.5        0.5        0.45833333 0.52941176 0.68181818]
# moy_spécificité: 0.53
#  ROC AUC:  [0.78557692 0.66272727 0.74001736 0.63850267 0.75818182]
# Mean ROC AUC: 0.72
# MCC : [0.32910134 0.13148952 0.28879795 0.27017702 0.35810951]
# MCC: 0.28
# GaussianNB
# Accuracy: [0.61111111 0.56944444 0.61111111 0.47222222 0.54166667]
# moy_accuracy: 0.56
# precision: [0.88571429 0.75862069 0.82352941 0.78571429 0.8       ]
# moy_precision: 0.81
# sensibilité : [0.57692308 0.52       0.58333333 0.47272727 0.4       ]
# moy_sensibilité: 0.51
# spécificité : [0.75       0.68181818 0.79166667 0.64705882 0.77272727]
# moy_spécificité: 0.73
#  ROC AUC:  [0.73365385 0.71363636 0.60633681 0.55668449 0.70454545]
# Mean ROC AUC: 0.66
# MCC : [0.27605909 0.24709372 0.27509212 0.040996   0.23045494]
# MCC: 0.21
# KNeighborsClassifier
# Accuracy: [0.63888889 0.65277778 0.625      0.5        0.68055556]
# moy_accuracy: 0.62
# precision: [0.78723404 0.81818182 0.92       0.83333333 0.86486486]
# moy_precision: 0.84
# sensibilité : [0.69230769 0.56       0.5        0.36363636 0.6       ]
# moy_sensibilité: 0.54
# spécificité : [0.6        0.72727273 0.875      0.70588235 0.72727273]
# moy_spécificité: 0.73
#  ROC AUC:  [0.63461538 0.69227273 0.70399306 0.56737968 0.74409091]
# Mean ROC AUC: 0.67
# MCC : [0.10482848 0.24709372 0.30429031 0.0564925  0.32006054]
# MCC: 0.21

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1.4,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    steps = [('over', SMOTE()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    # evaluate model
    scores1 = cross_val_score(pipeline, X6_1, y6, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))

# %% [markdown]
# # Cx_theileri

# %%
Clt = '/content/Classeurbb.xlsx'
datat1= pd.read_excel(Clt,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True)

# %%
del datat1["Source"]
del datat1["CodeSite"]
del datat1["VarT_ann_IRM"]
del datat1["VarT_tri_TempJ"]
del datat1["VarT_tri_TempN"]
del datat1["VarT_tri_NDVI"]
del datat1["VarT_tri_EVI"]
del datat1["Bio_Ta_moy"]
del datat1["Bio_Tint"]
del datat1["Bio_Tfr_Moy"]
del datat1["Bio_Pre_Ann"]
del datat1["Bio_Pre_Qfr"]
del datat1["Tmax_Janv"]
del datat1["Bio_Tj_Moy"]
del datat1["Min_TempN"]
datat1.head()
# Out:
#      X_long     Y_lat  Cx_theileri  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0 -15.91142  23.79474            0  ...       5.4       5.5       4.9
# 1 -13.18837  27.13295            0  ...       4.3       3.7       3.8
# 2 -13.18837  27.13295            0  ...       4.3       3.7       3.8
# 3 -13.18562  27.15794            1  ...       4.1       3.7       3.9
# 4 -13.16718  27.15773            0  ...       4.2       3.6       3.8
#
# [5 rows x 213 columns]

# %%
Xt1 = datat1.loc[:, datat1.columns != 'Cx_theileri']
yt1 = datat1.Cx_theileri

# %%
Xt1
# Out:
#         X_long      Y_lat    Bovins  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740  0.000000  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 3   -13.185620  27.157940  0.000000  ...       4.1       3.7       3.9
# 4   -13.167180  27.157730  0.000000  ...       4.2       3.6       3.8
# ..         ...        ...       ...  ...       ...       ...       ...
# 296  -5.283333  35.633333  0.000000  ...       3.9       3.4       3.8
# 297  -5.325286  35.685852  7.352805  ...       4.0       3.9       4.3
# 298  -5.833954  35.759465  0.000000  ...       3.5       3.8       3.9
# 299  -5.366667  35.766667  8.495770  ...       4.0       4.0       4.2
# 300  -5.816667  35.783333  0.000000  ...       3.6       3.8       4.0
#
# [301 rows x 212 columns]

# %%
yt1
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 296    1
# 297    1
# 298    1
# 299    1
# 300    1
# Name: Cx_theileri, Length: 301, dtype: int64

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC

classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
def tp(y_true, y_pred): 
    error= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
    return error

my_scorer = make_scorer(tp, greater_is_better=True)
my_scorer = make_scorer(tp, greater_is_better=True)
def tp1(y_true, y_pred): 
    MCC= matthews_corrcoef(y_true, y_pred)
    return MCC

my_scorer1 = make_scorer(tp1, greater_is_better=True)
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    fig, ax = plt.subplots(figsize=(11, 5))
    for i, (train, test) in enumerate(cv.split(Xt1, yt1)):
         clf.fit(Xt1.loc[train,], yt1.loc[train,])
         viz = plot_roc_curve(clf, Xt1.loc[test,], yt1.loc[test,],
                         name='ROC fold {}'.format(i),
                         alpha=0.3, lw=1, ax=ax)
         interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
         interp_tpr[0] = 0.0
         tprs.append(interp_tpr)
         aucs.append(viz.roc_auc)

    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=2, alpha=.8)

    ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="courbe roc %s " %name)
    ax.legend(loc="lower right")
    plt.show()
    # evaluate model
    scores = cross_val_score(clf, Xt1, yt1, scoring='accuracy', cv=cv, n_jobs=-1)
    scores1 = cross_val_score(clf, Xt1, yt1, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf, Xt1, yt1, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, Xt1, yt1, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, Xt1, yt1, scoring=my_scorer1, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
# Out:
# XGBClassifier
# Accuracy: [0.75409836 0.68333333 0.68333333 0.66666667 0.73333333]
# moy_accuracy: 0.70
# precision: [0.81395349 0.7        0.78947368 0.64444444 0.73809524]
# moy_precision: 0.74
# sensibilité : [0.83333333 0.8        0.73170732 0.87878788 0.86111111]
# moy_sensibilité: 0.82
# spécificité : [0.57894737 0.52       0.57894737 0.40740741 0.54166667]
# moy_spécificité: 0.53
# MCC : [0.41862385 0.33466401 0.29987724 0.32881335 0.43058756]
# MCC: 0.36
# LogisticRegression
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Accuracy: [0.67213115 0.61666667 0.63333333 0.61666667 0.6       ]
# moy_accuracy: 0.63
# precision: [0.84375    0.66666667 0.77142857 0.66666667 0.67647059]
# moy_precision: 0.72
# sensibilité : [0.64285714 0.68571429 0.65853659 0.60606061 0.63888889]
# moy_sensibilité: 0.65
# spécificité : [0.73684211 0.52       0.57894737 0.62962963 0.54166667]
# moy_spécificité: 0.60
# MCC : [0.35210095 0.20701967 0.22407787 0.23450882 0.17850139]
# MCC: 0.24
# RandomForestClassifier
# Accuracy: [0.80327869 0.73333333 0.75       0.7        0.7       ]
# moy_accuracy: 0.74
# precision: [0.8125     0.70212766 0.79545455 0.68292683 0.69565217]
# moy_precision: 0.74
# sensibilité : [0.92857143 0.94285714 0.85365854 0.84848485 0.88888889]
# moy_sensibilité: 0.89
# spécificité : [0.52631579 0.44       0.52631579 0.51851852 0.41666667]
# moy_spécificité: 0.49
# MCC : [0.51441412 0.45816317 0.3997023  0.39250046 0.3539192 ]
# MCC: 0.42
# GradientBoostingClassifier
# Accuracy: [0.80327869 0.71666667 0.7        0.65       0.73333333]
# moy_accuracy: 0.72
# precision: [0.85714286 0.71428571 0.7804878  0.63636364 0.72727273]
# moy_precision: 0.74
# sensibilité : [0.85714286 0.85714286 0.7804878  0.84848485 0.88888889]
# moy_sensibilité: 0.85
# spécificité : [0.68421053 0.52       0.52631579 0.40740741 0.5       ]
# moy_spécificité: 0.53
# MCC : [0.54135338 0.40574111 0.30680359 0.28787879 0.43082022]
# MCC: 0.39
# GaussianNB
# Accuracy: [0.68852459 0.65       0.63333333 0.56666667 0.68333333]
# moy_accuracy: 0.64
# precision: [0.81081081 0.68421053 0.74358974 0.58536585 0.72972973]
# moy_precision: 0.71
# sensibilité : [0.71428571 0.74285714 0.70731707 0.72727273 0.75      ]
# moy_sensibilité: 0.73
# spécificité : [0.63157895 0.52       0.47368421 0.37037037 0.58333333]
# moy_spécificité: 0.52
# MCC : [0.3278696  0.26891849 0.1765259  0.10442673 0.33586971]
# MCC: 0.24
# KNeighborsClassifier
# Accuracy: [0.57377049 0.56666667 0.61666667 0.66666667 0.58333333]
# moy_accuracy: 0.60
# precision: [0.83333333 0.69565217 0.82142857 0.68571429 0.67741935]
# moy_precision: 0.74
# sensibilité : [0.47619048 0.45714286 0.56097561 0.72727273 0.58333333]
# moy_sensibilité: 0.56
# spécificité : [0.78947368 0.72       0.73684211 0.59259259 0.58333333]
# moy_spécificité: 0.68
# MCC : [0.25184187 0.17962339 0.2776932  0.32277655 0.16339011]
# MCC: 0.24

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    # evaluate model
    scores1 = cross_val_score(clf, Xt1, yt1, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.67
# LogisticRegression
# accuracy: 0.64
# RandomForestClassifier
# accuracy: 0.72
# GradientBoostingClassifier
# accuracy: 0.73
# GaussianNB
# accuracy: 0.67
# KNeighborsClassifier
# accuracy: 0.59

# %% [markdown]
# **rééchantillonnage**

# %%
Xt_1=Xt1.values

# %%
Xt_1
# Out:
# array([[-1.59114200e+01,  2.37947400e+01,  0.00000000e+00, ...,
#          5.40000010e+00,  5.50000000e+00,  4.90000010e+00],
#        [-1.31883700e+01,  2.71329500e+01,  2.14420957e-04, ...,
#          4.30000019e+00,  3.70000005e+00,  3.79999995e+00],
#        [-1.31883700e+01,  2.71329500e+01,  2.14420957e-04, ...,
#          4.30000019e+00,  3.70000005e+00,  3.79999995e+00],
#        ...,
#        [-5.83395400e+00,  3.57594650e+01,  0.00000000e+00, ...,
#          3.50000000e+00,  3.79999995e+00,  3.90000010e+00],
#        [-5.36666700e+00,  3.57666670e+01,  8.49576950e+00, ...,
#          4.00000000e+00,  4.00000000e+00,  4.19999981e+00],
#        [-5.81666700e+00,  3.57833330e+01,  0.00000000e+00, ...,
#          3.59999990e+00,  3.79999995e+00,  4.00000000e+00]])

# %%
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    steps = [('over',ADASYN()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    print(name)
    scores = cross_val_score(pipeline, Xt_1, yt1, scoring="accuracy", cv=cv, n_jobs=-1)
    scores1 = cross_val_score(pipeline, Xt_1, yt1, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(pipeline, Xt_1, yt1, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(pipeline, Xt_1, yt1, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4= cross_val_score(pipeline, Xt_1, yt1, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores5 = cross_val_score(pipeline, Xt_1, yt1, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print(' ROC AUC: ' , scores4)
    print('Mean ROC AUC: %.2f' % mean(scores4))
    print('MCC :',scores5)
    print('MCC: %.2f' % mean(scores5))
# Out:
# XGBClassifier
# Accuracy: [0.78688525 0.63333333 0.7        0.63333333 0.7       ]
# moy_accuracy: 0.69
# precision: [0.83333333 0.70588235 0.8        0.6744186  0.75      ]
# moy_precision: 0.75
# sensibilité : [0.85714286 0.68571429 0.73170732 0.78787879 0.75      ]
# moy_sensibilité: 0.76
# spécificité : [0.63157895 0.64       0.68421053 0.55555556 0.5       ]
# moy_spécificité: 0.60
#  ROC AUC:  [0.7537594  0.72228571 0.6944801  0.69472503 0.67013889]
# Mean ROC AUC: 0.71
# MCC : [0.510554   0.26496224 0.32048203 0.15044516 0.36084392]
# MCC: 0.32
# LogisticRegression
# Accuracy: [0.6557377  0.63333333 0.66666667 0.6        0.65      ]
# moy_accuracy: 0.64
# precision: [0.80645161 0.72972973 0.84848485 0.66666667 0.68571429]
# moy_precision: 0.75
# sensibilité : [0.69047619 0.68571429 0.65853659 0.63636364 0.63888889]
# moy_sensibilité: 0.66
# spécificité : [0.63157895 0.6        0.78947368 0.59259259 0.66666667]
# moy_spécificité: 0.66
#  ROC AUC:  [0.68922306 0.73257143 0.67522465 0.61167228 0.66666667]
# Mean ROC AUC: 0.68
# MCC : [0.21497913 0.31428571 0.29675178 0.25925926 0.27602622]
# MCC: 0.27
# RandomForestClassifier
# Accuracy: [0.73770492 0.65       0.68333333 0.66666667 0.65      ]
# moy_accuracy: 0.68
# precision: [0.84210526 0.77419355 0.80555556 0.66666667 0.71428571]
# moy_precision: 0.76
# sensibilité : [0.76190476 0.65714286 0.68292683 0.75757576 0.72222222]
# moy_sensibilité: 0.72
# spécificité : [0.63157895 0.68       0.63157895 0.55555556 0.54166667]
# moy_spécificité: 0.61
#  ROC AUC:  [0.72619048 0.70971429 0.71630295 0.68799102 0.65740741]
# Mean ROC AUC: 0.70
# MCC : [0.3271412  0.39072951 0.24865922 0.31958166 0.33586971]
# MCC: 0.32
# GradientBoostingClassifier
# Accuracy: [0.78688525 0.7        0.63333333 0.66666667 0.61666667]
# moy_accuracy: 0.68
# precision: [0.82926829 0.75757576 0.76315789 0.7027027  0.71794872]
# moy_precision: 0.75
# sensibilité : [0.83333333 0.71428571 0.73170732 0.78787879 0.77777778]
# moy_sensibilité: 0.77
# spécificité : [0.57894737 0.68       0.57894737 0.59259259 0.54166667]
# moy_spécificité: 0.59
#  ROC AUC:  [0.76253133 0.78285714 0.7394095  0.75533109 0.69560185]
# Mean ROC AUC: 0.75
# MCC : [0.41862385 0.45868247 0.29987724 0.38931045 0.29651081]
# MCC: 0.37
# GaussianNB
# Accuracy: [0.54098361 0.68333333 0.6        0.56666667 0.68333333]
# moy_accuracy: 0.61
# precision: [0.78125    0.71052632 0.72972973 0.58536585 0.77419355]
# moy_precision: 0.72
# sensibilité : [0.57142857 0.8        0.70731707 0.72727273 0.72222222]
# moy_sensibilité: 0.71
# spécificité : [0.63157895 0.56       0.52631579 0.37037037 0.70833333]
# moy_spécificité: 0.56
#  ROC AUC:  [0.6660401  0.71085714 0.61745828 0.5959596  0.6724537 ]
# Mean ROC AUC: 0.65
# MCC : [0.23291238 0.33907114 0.2516433  0.10442673 0.34503278]
# MCC: 0.25
# KNeighborsClassifier
# Accuracy: [0.52459016 0.51666667 0.55       0.65       0.46666667]
# moy_accuracy: 0.54
# precision: [0.88888889 0.69230769 0.86363636 0.72413793 0.52941176]
# moy_precision: 0.74
# sensibilité : [0.4047619  0.28571429 0.41463415 0.63636364 0.25      ]
# moy_sensibilité: 0.40
# spécificité : [0.89473684 0.76       0.84210526 0.74074074 0.625     ]
# moy_spécificité: 0.77
#  ROC AUC:  [0.63909774 0.62057143 0.6957638  0.64478114 0.59548611]
# Mean ROC AUC: 0.64
# MCC : [ 0.26016197 -0.0133215   0.36746796  0.28880008 -0.09059765]
# MCC: 0.16

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    steps = [('over', ADASYN()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    # evaluate model
    scores1 = cross_val_score(pipeline, Xt_1, yt1, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.72
# LogisticRegression
# accuracy: 0.65
# RandomForestClassifier
# accuracy: 0.68
# GradientBoostingClassifier
# accuracy: 0.70
# GaussianNB
# accuracy: 0.64
# KNeighborsClassifier
# accuracy: 0.55

# %% [markdown]
# # CX_THEILERI _XGB

# %%
Clt2 = '/content/Classeurbb.xlsx'
datat2= pd.read_excel(Clt2,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True)

# %%
del datat2["Source"]
del datat2["CodeSite"]
datat2.head()
# Out:
#      X_long     Y_lat  Cx_theileri  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0 -15.91142  23.79474            0  ...       5.4       5.5       4.9
# 1 -13.18837  27.13295            0  ...       4.3       3.7       3.8
# 2 -13.18837  27.13295            0  ...       4.3       3.7       3.8
# 3 -13.18562  27.15794            1  ...       4.1       3.7       3.9
# 4 -13.16718  27.15773            0  ...       4.2       3.6       3.8
#
# [5 rows x 226 columns]

# %%
Xt2 = datat2.loc[:, datat2.columns != 'Cx_theileri']
yt2 = datat2.Cx_theileri

# %%
Xt2
# Out:
#         X_long      Y_lat    Bovins  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740  0.000000  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 3   -13.185620  27.157940  0.000000  ...       4.1       3.7       3.9
# 4   -13.167180  27.157730  0.000000  ...       4.2       3.6       3.8
# ..         ...        ...       ...  ...       ...       ...       ...
# 296  -5.283333  35.633333  0.000000  ...       3.9       3.4       3.8
# 297  -5.325286  35.685852  7.352805  ...       4.0       3.9       4.3
# 298  -5.833954  35.759465  0.000000  ...       3.5       3.8       3.9
# 299  -5.366667  35.766667  8.495770  ...       4.0       4.0       4.2
# 300  -5.816667  35.783333  0.000000  ...       3.6       3.8       4.0
#
# [301 rows x 225 columns]

# %%
selected_feat_TH_XGB = ['Volaille', 'Caprins', 'Autres', 'Pl_herb', 'Amp1_IRM', 'VarT_bi_IRM',
       'VarT_ann_TempJ', 'VarT_bi_TempJ', 'VarT_cy_TempJ', 'VarT_bi_TempN',
       'Bio_Pre_hum', 'Prec_Juill', 'Rad_Mars', 'Tmin_Fev', 'Vent_Nov']

# %%
Xt2=Xt2[selected_feat_TH_XGB]

# %%
yt2
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 296    1
# 297    1
# 298    1
# 299    1
# 300    1
# Name: Cx_theileri, Length: 301, dtype: int64

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC

classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
def tp(y_true, y_pred): 
    error= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
    return error

my_scorer = make_scorer(tp, greater_is_better=True)
my_scorer = make_scorer(tp, greater_is_better=True)
def tp1(y_true, y_pred): 
    MCC= matthews_corrcoef(y_true, y_pred)
    return MCC

my_scorer1 = make_scorer(tp1, greater_is_better=True)
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    fig, ax = plt.subplots(figsize=(11, 5))
    for i, (train, test) in enumerate(cv.split(Xt2, yt2)):
         clf.fit(Xt2.loc[train,], yt2.loc[train,])
         viz = plot_roc_curve(clf, Xt2.loc[test,], yt2.loc[test,],
                         name='ROC fold {}'.format(i),
                         alpha=0.3, lw=1, ax=ax)
         interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
         interp_tpr[0] = 0.0
         tprs.append(interp_tpr)
         aucs.append(viz.roc_auc)

    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=2, alpha=.8)

    ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="courbe roc %s " %name)
    ax.legend(loc="lower right")
    plt.show()
    # evaluate model
    scores = cross_val_score(clf, Xt2, yt2, scoring='accuracy', cv=cv, n_jobs=-1)
    scores1 = cross_val_score(clf, Xt2, yt2, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf, Xt2, yt2, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, Xt2, yt2, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, Xt2, yt2, scoring=my_scorer1, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
# Out:
# XGBClassifier
# Accuracy: [0.73770492 0.73333333 0.71666667 0.71666667 0.71666667]
# moy_accuracy: 0.72
# precision: [0.825      0.75675676 0.8        0.68181818 0.73170732]
# moy_precision: 0.76
# sensibilité : [0.78571429 0.8        0.7804878  0.90909091 0.83333333]
# moy_sensibilité: 0.82
# spécificité : [0.63157895 0.64       0.57894737 0.48148148 0.54166667]
# moy_spécificité: 0.57
# MCC : [0.40672713 0.44616133 0.35468621 0.43939394 0.39492935]
# MCC: 0.41
# LogisticRegression
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Accuracy: [0.67213115 0.58333333 0.63333333 0.6        0.71666667]
# moy_accuracy: 0.64
# precision: [0.78947368 0.66666667 0.74358974 0.60465116 0.78787879]
# moy_precision: 0.72
# sensibilité : [0.71428571 0.57142857 0.70731707 0.78787879 0.72222222]
# moy_sensibilité: 0.70
# spécificité : [0.57894737 0.6        0.47368421 0.37037037 0.70833333]
# moy_spécificité: 0.55
# MCC : [0.28019391 0.16903085 0.1765259  0.17471153 0.4239818 ]
# MCC: 0.24
# RandomForestClassifier
# Accuracy: [0.7704918  0.73333333 0.71666667 0.68333333 0.75      ]
# moy_accuracy: 0.73
# precision: [0.78       0.68627451 0.75       0.65909091 0.72340426]
# moy_precision: 0.72
# sensibilité : [0.92857143 1.         0.87804878 0.87878788 0.94444444]
# moy_sensibilité: 0.93
# spécificité : [0.42105263 0.36       0.36842105 0.44444444 0.45833333]
# moy_spécificité: 0.41
# MCC : [0.42113507 0.49705012 0.28662975 0.36363636 0.47896278]
# MCC: 0.41
# GradientBoostingClassifier
# Accuracy: [0.75409836 0.7        0.73333333 0.66666667 0.7       ]
# moy_accuracy: 0.71
# precision: [0.8        0.72972973 0.79069767 0.65853659 0.725     ]
# moy_precision: 0.74
# sensibilité : [0.85714286 0.77142857 0.82926829 0.81818182 0.80555556]
# moy_sensibilité: 0.82
# spécificité : [0.52631579 0.6        0.52631579 0.48148148 0.54166667]
# moy_spécificité: 0.54
# MCC : [0.40369534 0.37662969 0.36707292 0.32048203 0.36084392]
# MCC: 0.37
# GaussianNB
# Accuracy: [0.72131148 0.66666667 0.61666667 0.6        0.66666667]
# moy_accuracy: 0.65
# precision: [0.75510204 0.65957447 0.70454545 0.59574468 0.68181818]
# moy_precision: 0.68
# sensibilité : [0.88095238 0.88571429 0.75609756 0.84848485 0.83333333]
# moy_sensibilité: 0.84
# spécificité : [0.36842105 0.36       0.31578947 0.2962963  0.41666667]
# moy_spécificité: 0.35
# MCC : [0.29051126 0.29404502 0.07561935 0.17483575 0.27695585]
# MCC: 0.22
# KNeighborsClassifier
# Accuracy: [0.52459016 0.61666667 0.66666667 0.55       0.7       ]
# moy_accuracy: 0.61
# precision: [0.76       0.73076923 0.83870968 0.58823529 0.75      ]
# moy_precision: 0.73
# sensibilité : [0.45238095 0.54285714 0.63414634 0.60606061 0.75      ]
# moy_sensibilité: 0.60
# spécificité : [0.68421053 0.72       0.73684211 0.48148148 0.625     ]
# moy_spécificité: 0.65
# MCC : [0.12861861 0.26151565 0.3453419  0.08788801 0.375     ]
# MCC: 0.24

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    # evaluate model
    scores1 = cross_val_score(clf, Xt2, yt2, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.71
# LogisticRegression
# accuracy: 0.64
# RandomForestClassifier
# accuracy: 0.70
# GradientBoostingClassifier
# accuracy: 0.74
# GaussianNB
# accuracy: 0.67
# KNeighborsClassifier
# accuracy: 0.64

# %% [markdown]
# **rééchantionnage**

# %%
Xt_2=Xt2.values

# %%
Xt_2
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.12760000e+04, 1.48000002e+01, 5.50000000e+00],
#        [0.00000000e+00, 6.34491816e-02, 0.00000000e+00, ...,
#         1.99970000e+04, 1.28000002e+01, 3.70000005e+00],
#        [0.00000000e+00, 6.34491816e-02, 0.00000000e+00, ...,
#         1.99970000e+04, 1.28000002e+01, 3.70000005e+00],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         1.55350000e+04, 9.50000000e+00, 3.79999995e+00],
#        [1.05550156e+02, 8.69140530e+00, 3.00000000e+01, ...,
#         1.53300000e+04, 9.60000038e+00, 4.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         1.54450000e+04, 1.06999998e+01, 3.79999995e+00]])

# %%
yt2
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 296    1
# 297    1
# 298    1
# 299    1
# 300    1
# Name: Cx_theileri, Length: 301, dtype: int64

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    steps = [('over', SMOTE()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    print(name)
    scores = cross_val_score(pipeline, Xt_2, yt2, scoring="accuracy", cv=cv, n_jobs=-1)
    scores1 = cross_val_score(pipeline, Xt_2, yt2, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(pipeline, Xt_2, yt2, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(pipeline, Xt_2, yt2, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4= cross_val_score(pipeline, Xt_2, yt2, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores5 = cross_val_score(pipeline, Xt_2, yt2, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print(' ROC AUC: ' , scores4)
    print('Mean ROC AUC: %.2f' % mean(scores4))
    print('MCC :',scores5)
    print('MCC: %.2f' % mean(scores5))
# Out:
# XGBClassifier
# Accuracy: [0.68852459 0.75       0.76666667 0.66666667 0.68333333]
# moy_accuracy: 0.71
# precision: [0.81081081 0.79411765 0.8        0.7027027  0.70731707]
# moy_precision: 0.76
# sensibilité : [0.80952381 0.68571429 0.75609756 0.78787879 0.75      ]
# moy_sensibilité: 0.76
# spécificité : [0.63157895 0.68       0.63157895 0.59259259 0.54166667]
# moy_spécificité: 0.62
#  ROC AUC:  [0.79636591 0.736      0.70603338 0.69135802 0.75578704]
# Mean ROC AUC: 0.74
# MCC : [0.5452614  0.52663543 0.29987724 0.38931045 0.32810304]
# MCC: 0.42
# LogisticRegression
# Accuracy: [0.67213115 0.61666667 0.61666667 0.61666667 0.65      ]
# moy_accuracy: 0.63
# precision: [0.83783784 0.70967742 0.74358974 0.64102564 0.77419355]
# moy_precision: 0.74
# sensibilité : [0.71428571 0.62857143 0.70731707 0.75757576 0.63888889]
# moy_sensibilité: 0.69
# spécificité : [0.47368421 0.6        0.47368421 0.44444444 0.70833333]
# moy_spécificité: 0.54
#  ROC AUC:  [0.72243108 0.66742857 0.65853659 0.67227834 0.63773148]
# Mean ROC AUC: 0.67
# MCC : [0.29252042 0.33261218 0.2516433  0.24934393 0.31581015]
# MCC: 0.29
# RandomForestClassifier
# Accuracy: [0.75409836 0.7        0.73333333 0.65       0.71666667]
# moy_accuracy: 0.71
# precision: [0.85       0.73529412 0.775      0.63157895 0.71794872]
# moy_precision: 0.74
# sensibilité : [0.80952381 0.65714286 0.73170732 0.72727273 0.77777778]
# moy_sensibilité: 0.74
# spécificité : [0.57894737 0.64       0.52631579 0.51851852 0.5       ]
# moy_spécificité: 0.55
#  ROC AUC:  [0.74749373 0.704      0.6970475  0.72390572 0.71875   ]
# Mean ROC AUC: 0.72
# MCC : [0.40369534 0.26496224 0.40187811 0.28426762 0.36084392]
# MCC: 0.34
# GradientBoostingClassifier
# Accuracy: [0.72131148 0.68333333 0.7        0.68333333 0.68333333]
# moy_accuracy: 0.69
# precision: [0.81395349 0.73529412 0.81081081 0.63157895 0.71794872]
# moy_precision: 0.74
# sensibilité : [0.80952381 0.71428571 0.70731707 0.72727273 0.77777778]
# moy_sensibilité: 0.75
# spécificité : [0.73684211 0.68       0.52631579 0.55555556 0.5       ]
# moy_spécificité: 0.60
#  ROC AUC:  [0.82894737 0.712      0.72657253 0.70145903 0.70486111]
# Mean ROC AUC: 0.73
# MCC : [0.55573827 0.42916625 0.27868203 0.21882932 0.40584256]
# MCC: 0.38
# GaussianNB
# Accuracy: [0.73770492 0.66666667 0.66666667 0.6        0.71666667]
# moy_accuracy: 0.68
# precision: [0.76595745 0.68181818 0.75       0.60869565 0.71428571]
# moy_precision: 0.70
# sensibilité : [0.85714286 0.85714286 0.68292683 0.84848485 0.83333333]
# moy_sensibilité: 0.82
# spécificité : [0.42105263 0.4        0.52631579 0.2962963  0.54166667]
# moy_spécificité: 0.44
#  ROC AUC:  [0.66729323 0.72342857 0.58151476 0.6318743  0.66435185]
# Mean ROC AUC: 0.65
# MCC : [0.34152563 0.29277002 0.22552751 0.17483575 0.36084392]
# MCC: 0.28
# KNeighborsClassifier
# Accuracy: [0.50819672 0.56666667 0.6        0.55       0.58333333]
# moy_accuracy: 0.56
# precision: [0.72727273 0.70833333 0.84615385 0.57142857 0.73076923]
# moy_precision: 0.72
# sensibilité : [0.4047619  0.48571429 0.43902439 0.48484848 0.63888889]
# moy_sensibilité: 0.49
# spécificité : [0.78947368 0.72       0.73684211 0.55555556 0.75      ]
# moy_spécificité: 0.71
#  ROC AUC:  [0.62218045 0.65885714 0.73876765 0.62121212 0.67997685]
# Mean ROC AUC: 0.66
# MCC : [0.106914   0.22215006 0.32935148 0.13743154 0.34020691]
# MCC: 0.23

# %%
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
def tp(y_true, y_pred): 
    error= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
    return error

my_scorer = make_scorer(tp, greater_is_better=True)
my_scorer = make_scorer(tp, greater_is_better=True)
def tp1(y_true, y_pred): 
    MCC= matthews_corrcoef(y_true, y_pred)
    return MCC

my_scorer1 = make_scorer(tp1, greater_is_better=True)

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    steps = [('over', ADASYN()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    print(name)
    scores = cross_val_score(pipeline, Xt_2, yt2, scoring="accuracy", cv=cv, n_jobs=-1)
    scores1 = cross_val_score(pipeline, Xt_2, yt2, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(pipeline, Xt_2, yt2, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(pipeline, Xt_2, yt2, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4= cross_val_score(pipeline, Xt_2, yt2, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores5 = cross_val_score(pipeline, Xt_2, yt2, scoring=my_scorer1, cv=cv, n_jobs=-1)

    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print(' ROC AUC: ' , scores4)
    print('Mean ROC AUC: %.2f' % mean(scores4))
    print('MCC :',scores5)
    print('MCC: %.2f' % mean(scores5))
# Out:
# XGBClassifier
# Accuracy: [0.72131148 0.68333333 0.68333333 0.68333333 0.65      ]
# moy_accuracy: 0.68
# precision: [0.82051282 0.78125    0.83333333 0.66666667 0.71794872]
# moy_precision: 0.76
# sensibilité : [0.80952381 0.68571429 0.70731707 0.72727273 0.75      ]
# moy_sensibilité: 0.74
# spécificité : [0.73684211 0.72       0.57894737 0.59259259 0.54166667]
# moy_spécificité: 0.63
#  ROC AUC:  [0.80639098 0.73485714 0.72657253 0.70931538 0.69791667]
# Mean ROC AUC: 0.74
# MCC : [0.42627792 0.45868247 0.34757852 0.39072951 0.29651081]
# MCC: 0.38
# LogisticRegression
# Accuracy: [0.67213115 0.63333333 0.63333333 0.63333333 0.66666667]
# moy_accuracy: 0.65
# precision: [0.81081081 0.75757576 0.77777778 0.65789474 0.72413793]
# moy_precision: 0.75
# sensibilité : [0.69047619 0.6        0.68292683 0.6969697  0.63888889]
# moy_sensibilité: 0.66
# spécificité : [0.57894737 0.72       0.52631579 0.48148148 0.70833333]
# moy_spécificité: 0.60
#  ROC AUC:  [0.71992481 0.70971429 0.60462131 0.64309764 0.68055556]
# Mean ROC AUC: 0.67
# MCC : [0.23127749 0.36140316 0.10238909 0.21320072 0.36762776]
# MCC: 0.26
# RandomForestClassifier
# Accuracy: [0.73770492 0.65       0.68333333 0.65       0.7       ]
# moy_accuracy: 0.68
# precision: [0.80487805 0.66666667 0.8        0.67567568 0.71052632]
# moy_precision: 0.73
# sensibilité : [0.80952381 0.54285714 0.70731707 0.72727273 0.77777778]
# moy_sensibilité: 0.71
# spécificité : [0.63157895 0.68       0.63157895 0.59259259 0.5       ]
# moy_spécificité: 0.61
#  ROC AUC:  [0.78508772 0.67885714 0.68292683 0.70482604 0.70949074]
# Mean ROC AUC: 0.71
# MCC : [0.46491228 0.24846467 0.32676071 0.28721348 0.29651081]
# MCC: 0.32
# GradientBoostingClassifier
# Accuracy: [0.80327869 0.65       0.73333333 0.66666667 0.68333333]
# moy_accuracy: 0.71
# precision: [0.83333333 0.74193548 0.83333333 0.67567568 0.73684211]
# moy_precision: 0.76
# sensibilité : [0.85714286 0.65714286 0.70731707 0.72727273 0.77777778]
# moy_sensibilité: 0.75
# spécificité : [0.52631579 0.68       0.63157895 0.62962963 0.54166667]
# moy_spécificité: 0.60
#  ROC AUC:  [0.79385965 0.75885714 0.72528883 0.71156004 0.70486111]
# Mean ROC AUC: 0.74
# MCC : [0.40369534 0.31622777 0.34757852 0.32040595 0.40584256]
# MCC: 0.36
# GaussianNB
# Accuracy: [0.73770492 0.68333333 0.65       0.6        0.7       ]
# moy_accuracy: 0.67
# precision: [0.77083333 0.68181818 0.76315789 0.60869565 0.69767442]
# moy_precision: 0.70
# sensibilité : [0.88095238 0.85714286 0.70731707 0.84848485 0.83333333]
# moy_sensibilité: 0.83
# spécificité : [0.42105263 0.48       0.52631579 0.2962963  0.5       ]
# moy_spécificité: 0.44
#  ROC AUC:  [0.65977444 0.71085714 0.58023107 0.62401796 0.66203704]
# Mean ROC AUC: 0.65
# MCC : [0.34152563 0.33127067 0.12667365 0.21386181 0.31709178]
# MCC: 0.27
# KNeighborsClassifier
# Accuracy: [0.47540984 0.55       0.58333333 0.56666667 0.6       ]
# moy_accuracy: 0.56
# precision: [0.80952381 0.72727273 0.80952381 0.64       0.79166667]
# moy_precision: 0.76
# sensibilité : [0.35714286 0.42857143 0.41463415 0.48484848 0.41666667]
# moy_sensibilité: 0.42
# spécificité : [0.78947368 0.72       0.84210526 0.7037037  0.83333333]
# moy_spécificité: 0.78
#  ROC AUC:  [0.60651629 0.66685714 0.68164313 0.57744108 0.69444444]
# Mean ROC AUC: 0.65
# MCC : [0.16812432 0.22215006 0.12394372 0.18253663 0.29388599]
# MCC: 0.20

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    steps = [('over', SMOTE()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    # evaluate model
    scores1 = cross_val_score(pipeline, Xt_2, yt2, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.70
# LogisticRegression
# accuracy: 0.64
# RandomForestClassifier
# accuracy: 0.69
# GradientBoostingClassifier
# accuracy: 0.69
# GaussianNB
# accuracy: 0.69
# KNeighborsClassifier
# accuracy: 0.58

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    steps = [('over', ADASYN()), ('model', clf)]
    pipeline = Pipeline(steps=steps)
    # evaluate model
    scores1 = cross_val_score(pipeline, Xt_2, yt2, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.70
# LogisticRegression
# accuracy: 0.65
# RandomForestClassifier
# accuracy: 0.67
# GradientBoostingClassifier
# accuracy: 0.70
# GaussianNB
# accuracy: 0.66
# KNeighborsClassifier
# accuracy: 0.54

# %% [markdown]
# # Cx-theileri_rg

# %%
Clt3 = '/content/Classeurbb.xlsx'
datat3= pd.read_excel(Clt3,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True)

# %%
del datat3["Source"]
del datat3["CodeSite"]
datat3.head()
# Out:
#      X_long     Y_lat  Cx_theileri  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0 -15.91142  23.79474            0  ...       5.4       5.5       4.9
# 1 -13.18837  27.13295            0  ...       4.3       3.7       3.8
# 2 -13.18837  27.13295            0  ...       4.3       3.7       3.8
# 3 -13.18562  27.15794            1  ...       4.1       3.7       3.9
# 4 -13.16718  27.15773            0  ...       4.2       3.6       3.8
#
# [5 rows x 226 columns]

# %%
selected_feat_cxthe_re =["Vent_Juill","Moy_NDVI","Prec_Nov","Amp3_NDVI","Vent_Janv","Vent_Sept","Prec_Oct","Bio_Tj_Moy","VarT_ann_TempJ","VarT_ann_TempN","Amp3_TempJ","Vent_Mars","Vent_Oct"]

# %%
Xt3 = datat3.loc[:, datat3.columns != 'Cx_theileri']
yt3 = datat3.Cx_theileri

# %%
Xt3
# Out:
#         X_long      Y_lat    Bovins  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740  0.000000  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950  0.000214  ...       4.3       3.7       3.8
# 3   -13.185620  27.157940  0.000000  ...       4.1       3.7       3.9
# 4   -13.167180  27.157730  0.000000  ...       4.2       3.6       3.8
# ..         ...        ...       ...  ...       ...       ...       ...
# 296  -5.283333  35.633333  0.000000  ...       3.9       3.4       3.8
# 297  -5.325286  35.685852  7.352805  ...       4.0       3.9       4.3
# 298  -5.833954  35.759465  0.000000  ...       3.5       3.8       3.9
# 299  -5.366667  35.766667  8.495770  ...       4.0       4.0       4.2
# 300  -5.816667  35.783333  0.000000  ...       3.6       3.8       4.0
#
# [301 rows x 225 columns]

# %%
Xt3=Xt3[selected_feat_cxthe_re]

# %%
Xt3
# Out:
#      Vent_Juill  Moy_NDVI  Prec_Nov  ...  Amp3_TempJ  Vent_Mars  Vent_Oct
# 0           7.5      1106         4  ...           7        6.1       5.4
# 1           5.9      1082         7  ...          31        4.8       4.3
# 2           5.9      1082         7  ...          31        4.8       4.3
# 3           6.2      1090         7  ...          23        5.1       4.1
# 4           6.2      1060         6  ...          33        5.0       4.2
# ..          ...       ...       ...  ...         ...        ...       ...
# 296         4.0      1204        70  ...           0        4.6       3.9
# 297         4.0      1211        77  ...           7        4.5       4.0
# 298         3.6      1222       126  ...          14        4.2       3.5
# 299         3.9      1512        90  ...           5        4.6       4.0
# 300         3.7      1231       128  ...           1        4.6       3.6
#
# [301 rows x 13 columns]

# %%
yt3
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 296    1
# 297    1
# 298    1
# 299    1
# 300    1
# Name: Cx_theileri, Length: 301, dtype: int64

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)
}
def tp(y_true, y_pred): 
    error= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
    return error

my_scorer = make_scorer(tp, greater_is_better=True)
my_scorer = make_scorer(tp, greater_is_better=True)
def tp1(y_true, y_pred): 
    MCC= matthews_corrcoef(y_true, y_pred)
    return MCC

my_scorer1 = make_scorer(tp1, greater_is_better=True)
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    fig, ax = plt.subplots(figsize=(11, 5))
    for i, (train, test) in enumerate(cv.split(Xt3, yt3)):
         clf.fit(Xt3.loc[train,], yt3.loc[train,])
         viz = plot_roc_curve(clf, Xt3.loc[test,], yt3.loc[test,],
                         name='ROC fold {}'.format(i),
                         alpha=0.3, lw=1, ax=ax)
         interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
         interp_tpr[0] = 0.0
         tprs.append(interp_tpr)
         aucs.append(viz.roc_auc)

    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=2, alpha=.8)

    ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="courbe roc %s " %name)
    ax.legend(loc="lower right")
    plt.show()
    # evaluate model
    scores = cross_val_score(clf, Xt3, yt3, scoring='accuracy', cv=cv, n_jobs=-1)
    scores1 = cross_val_score(clf, Xt3, yt3, scoring='precision', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf, Xt3, yt3, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, Xt3, yt3, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, Xt3, yt3, scoring=my_scorer1, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores)
    print('moy_accuracy: %.2f' % mean(scores))
    print('precision:',scores1)
    print('moy_precision: %.2f' % mean(scores1))
    print('sensibilité :',scores2)
    print('moy_sensibilité: %.2f' % mean(scores2))
    print('spécificité :',scores3)
    print('moy_spécificité: %.2f' % mean(scores3))
    print('MCC :',scores4)
    print('MCC: %.2f' % mean(scores4))
# Out:
# XGBClassifier
# Accuracy: [0.70491803 0.71666667 0.8        0.65       0.66666667]
# moy_accuracy: 0.71
# precision: [0.77272727 0.725      0.85365854 0.64285714 0.69047619]
# moy_precision: 0.74
# sensibilité : [0.80952381 0.82857143 0.85365854 0.81818182 0.80555556]
# moy_sensibilité: 0.82
# spécificité : [0.47368421 0.56       0.68421053 0.44444444 0.45833333]
# moy_spécificité: 0.52
# MCC : [0.29252042 0.40637773 0.53786906 0.2851124  0.28210909]
# MCC: 0.36
# LogisticRegression
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Accuracy: [0.70491803 0.76666667 0.73333333 0.66666667 0.56666667]
# moy_accuracy: 0.69
# precision: [0.85294118 0.78378378 0.87878788 0.68571429 0.66666667]
# moy_precision: 0.77
# sensibilité : [0.69047619 0.82857143 0.70731707 0.72727273 0.55555556]
# moy_sensibilité: 0.70
# spécificité : [0.73684211 0.68       0.78947368 0.59259259 0.58333333]
# moy_spécificité: 0.68
# MCC : [0.39841125 0.51569296 0.46451889 0.32277655 0.13608276]
# MCC: 0.37
# RandomForestClassifier
# Accuracy: [0.80327869 0.76666667 0.75       0.65       0.7       ]
# moy_accuracy: 0.73
# precision: [0.8        0.73333333 0.7826087  0.63636364 0.69565217]
# moy_precision: 0.73
# sensibilité : [0.95238095 0.94285714 0.87804878 0.84848485 0.88888889]
# moy_sensibilité: 0.90
# spécificité : [0.47368421 0.52       0.47368421 0.40740741 0.41666667]
# moy_spécificité: 0.46
# MCC : [0.5132112  0.52698604 0.3868467  0.28787879 0.3539192 ]
# MCC: 0.41
# GradientBoostingClassifier
# Accuracy: [0.70491803 0.68333333 0.8        0.6        0.68333333]
# moy_accuracy: 0.69
# precision: [0.8        0.71052632 0.85365854 0.62162162 0.70731707]
# moy_precision: 0.74
# sensibilité : [0.76190476 0.77142857 0.85365854 0.6969697  0.80555556]
# moy_sensibilité: 0.78
# spécificité : [0.57894737 0.56       0.68421053 0.48148148 0.5       ]
# moy_spécificité: 0.56
# MCC : [0.33222156 0.33907114 0.53786906 0.18259694 0.32179428]
# MCC: 0.34
# GaussianNB
# Accuracy: [0.70491803 0.6        0.68333333 0.58333333 0.63333333]
# moy_accuracy: 0.64
# precision: [0.76086957 0.61702128 0.75       0.58333333 0.65217391]
# moy_precision: 0.67
# sensibilité : [0.83333333 0.82857143 0.80487805 0.84848485 0.83333333]
# moy_sensibilité: 0.83
# spécificité : [0.42105263 0.28       0.42105263 0.25925926 0.33333333]
# moy_spécificité: 0.34
# MCC : [0.27357099 0.12992687 0.23766083 0.13400504 0.19304684]
# MCC: 0.19
# KNeighborsClassifier
# Accuracy: [0.7704918  0.7        0.65       0.53333333 0.6       ]
# moy_accuracy: 0.65
# precision: [0.91176471 0.81481481 0.79411765 0.57575758 0.67647059]
# moy_precision: 0.75
# sensibilité : [0.73809524 0.62857143 0.65853659 0.57575758 0.63888889]
# moy_sensibilité: 0.65
# spécificité : [0.84210526 0.8        0.63157895 0.48148148 0.54166667]
# moy_spécificité: 0.66
# MCC : [0.54095134 0.42470599 0.27234134 0.05723906 0.17850139]
# MCC: 0.29

# %%
classifiers = {
    "XGBClassifier": XGBClassifier(scale_pos_weight=1,learning_rate=0.1),
    "LogisticRegression": LogisticRegression(max_iter=100, solver='lbfgs', class_weight='balanced', random_state=11),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=150, criterion='gini', max_depth=5, random_state=11),
    "GradientBoostingClassifier":GradientBoostingClassifier(n_estimators=225, learning_rate=0.1, max_features=2, max_depth=2, random_state=0,min_samples_leaf=2,subsample=1)
,
    "GaussianNB" : GaussianNB(),
    "KNeighborsClassifier" : KNeighborsClassifier(n_neighbors=4)

}
for name, clf in classifiers.items():
    print(name)
    # prepare the cross-validation procedure
    loo =LeaveOneOut()
    # evaluate model
    scores1 = cross_val_score(clf, Xt3, yt3, scoring='accuracy', cv=loo, n_jobs=-1)
    # report performance
    print('accuracy: %.2f' % mean(scores1))
# Out:
# XGBClassifier
# accuracy: 0.70
# LogisticRegression
# accuracy: 0.68
# RandomForestClassifier
# accuracy: 0.73
# GradientBoostingClassifier
# accuracy: 0.70
# GaussianNB
# accuracy: 0.65
# KNeighborsClassifier
# accuracy: 0.64
