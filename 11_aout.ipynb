# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/pfe/blob/main/11_aout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score

from mlxtend.feature_selection import SequentialFeatureSelector as SFS
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy 
import sklearn.metrics as metrics
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC

# %%
Cl1 = '/content/Classeurcc.xlsx'
data1= pd.read_excel(Cl1,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True)

# %%
data1
# Out:
#        Source     CodeSite     X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0    Bennouna  Z01-S01-G01 -15.911420  ...       5.4       5.5       4.9
# 1    Bennouna  Z01-S05-G01 -13.188370  ...       4.3       3.7       3.8
# 2    Bennouna  Z01-S05-G02 -13.188370  ...       4.3       3.7       3.8
# 3    Bennouna  Z01-S07-G01 -13.185620  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.167180  ...       4.2       3.6       3.8
# ..        ...          ...        ...  ...       ...       ...       ...
# 255     Trari    Trari_269  -5.366667  ...       4.0       4.0       4.2
# 256     Trari    Trari_270  -5.816667  ...       3.6       3.8       4.0
# 257     Trari    Trari_273  -5.366667  ...       4.0       3.9       4.3
# 258     Trari    Trari_274  -5.558611  ...       3.6       3.4       3.6
# 259     Trari    Trari_275  -5.483333  ...       4.0       4.0       4.2
#
# [260 rows x 228 columns]

# %%
data1.head()
# Out:
#      Source     CodeSite    X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0  Bennouna  Z01-S01-G01 -15.91142  ...       5.4       5.5       4.9
# 1  Bennouna  Z01-S05-G01 -13.18837  ...       4.3       3.7       3.8
# 2  Bennouna  Z01-S05-G02 -13.18837  ...       4.3       3.7       3.8
# 3  Bennouna  Z01-S07-G01 -13.18562  ...       4.1       3.7       3.9
# 4  Bennouna  Z01-S08-G01 -13.16718  ...       4.2       3.6       3.8
#
# [5 rows x 228 columns]

# %%
data1["Cs_longia"][0]
# Out:
# 1

# %%
P=0
for i in range(260):
 if data1["Cs_longia"][i]==1 :
   P = P + 1
print(P)
# Out:
# 127

# %%
N=0
for i in range(260):
 if data1["Cs_longia"][i]==0 :
   N = N + 1
print(N)
# Out:
# 133

# %% [markdown]
# *   random sample :

# %%
from random import sample

# %%
data1[data1['Cs_longia']==0].sample(n=6, random_state=1)
# Out:
#        Source     CodeSite     X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 108  Bennouna  Z05-S08-G01  -7.195120  ...       2.2       2.3       2.2
# 61   Bennouna  Z03-S04-G01  -7.665210  ...       2.8       2.5       2.9
# 82   Bennouna  Z04-S07-G01  -6.721142  ...       2.9       2.8       2.8
# 11   Bennouna  Z01-S12-G03 -13.214230  ...       4.4       3.6       3.8
# 64   Bennouna  Z03-S06-G01  -7.971831  ...       2.3       2.1       2.3
# 153  Bennouna  Z06-S31-G01  -5.841000  ...       2.7       2.3       2.3
#
# [6 rows x 228 columns]

# %%
data1["CodeSite"][11]
# Out:
# 'Z01-S12-G03'

# %%
data1=data1.drop(11)

# %%
data1
# Out:
#        Source     CodeSite     X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0    Bennouna  Z01-S01-G01 -15.911420  ...       5.4       5.5       4.9
# 1    Bennouna  Z01-S05-G01 -13.188370  ...       4.3       3.7       3.8
# 2    Bennouna  Z01-S05-G02 -13.188370  ...       4.3       3.7       3.8
# 3    Bennouna  Z01-S07-G01 -13.185620  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.167180  ...       4.2       3.6       3.8
# ..        ...          ...        ...  ...       ...       ...       ...
# 255     Trari    Trari_269  -5.366667  ...       4.0       4.0       4.2
# 256     Trari    Trari_270  -5.816667  ...       3.6       3.8       4.0
# 257     Trari    Trari_273  -5.366667  ...       4.0       3.9       4.3
# 258     Trari    Trari_274  -5.558611  ...       3.6       3.4       3.6
# 259     Trari    Trari_275  -5.483333  ...       4.0       4.0       4.2
#
# [259 rows x 228 columns]

# %%
data1["CodeSite"][61]
# Out:
# 'Z03-S04-G01'

# %%
data1=data1.drop(61)

# %%
(data1[data1["Cs_longia"]==0]).count
# Out:
# <bound method DataFrame.count of        Source     CodeSite    X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 3    Bennouna  Z01-S07-G01 -13.18562  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.16718  ...       4.2       3.6       3.8
# 5    Bennouna  Z01-S09-G01 -13.20156  ...       4.6       3.8       3.9
# 6    Bennouna  Z01-S11-G01 -13.20700  ...       4.6       3.8       3.9
# 7    Bennouna  Z01-S11-G02 -13.20700  ...       4.6       3.8       3.9
# ..        ...          ...       ...  ...       ...       ...       ...
# 161  Bennouna  Z07-S07-G01  -6.20400  ...       3.1       3.5       3.3
# 163  Bennouna  Z07-S09-G01  -6.91000  ...       2.7       2.9       2.8
# 164  Bennouna  Z07-S10-G01  -6.86400  ...       3.4       3.4       3.6
# 165  Bennouna  Z07-S11-G01  -6.88600  ...       2.8       2.9       2.6
# 166  Bennouna  Z07-S12-G01  -5.00000  ...       3.4       2.8       3.0
#
# [131 rows x 228 columns]>

# %%
data1
# Out:
#        Source     CodeSite     X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0    Bennouna  Z01-S01-G01 -15.911420  ...       5.4       5.5       4.9
# 1    Bennouna  Z01-S05-G01 -13.188370  ...       4.3       3.7       3.8
# 2    Bennouna  Z01-S05-G02 -13.188370  ...       4.3       3.7       3.8
# 3    Bennouna  Z01-S07-G01 -13.185620  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.167180  ...       4.2       3.6       3.8
# ..        ...          ...        ...  ...       ...       ...       ...
# 255     Trari    Trari_269  -5.366667  ...       4.0       4.0       4.2
# 256     Trari    Trari_270  -5.816667  ...       3.6       3.8       4.0
# 257     Trari    Trari_273  -5.366667  ...       4.0       3.9       4.3
# 258     Trari    Trari_274  -5.558611  ...       3.6       3.4       3.6
# 259     Trari    Trari_275  -5.483333  ...       4.0       4.0       4.2
#
# [258 rows x 228 columns]

# %%
data1["CodeSite"][64]
# Out:
# 'Z03-S06-G01'

# %%
data1=data1.drop(64)

# %%
(data1[data1["Cs_longia"]==0]).count
# Out:
# <bound method DataFrame.count of        Source     CodeSite    X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 3    Bennouna  Z01-S07-G01 -13.18562  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.16718  ...       4.2       3.6       3.8
# 5    Bennouna  Z01-S09-G01 -13.20156  ...       4.6       3.8       3.9
# 6    Bennouna  Z01-S11-G01 -13.20700  ...       4.6       3.8       3.9
# 7    Bennouna  Z01-S11-G02 -13.20700  ...       4.6       3.8       3.9
# ..        ...          ...       ...  ...       ...       ...       ...
# 161  Bennouna  Z07-S07-G01  -6.20400  ...       3.1       3.5       3.3
# 163  Bennouna  Z07-S09-G01  -6.91000  ...       2.7       2.9       2.8
# 164  Bennouna  Z07-S10-G01  -6.86400  ...       3.4       3.4       3.6
# 165  Bennouna  Z07-S11-G01  -6.88600  ...       2.8       2.9       2.6
# 166  Bennouna  Z07-S12-G01  -5.00000  ...       3.4       2.8       3.0
#
# [130 rows x 228 columns]>

# %%
data1
# Out:
#        Source     CodeSite     X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0    Bennouna  Z01-S01-G01 -15.911420  ...       5.4       5.5       4.9
# 1    Bennouna  Z01-S05-G01 -13.188370  ...       4.3       3.7       3.8
# 2    Bennouna  Z01-S05-G02 -13.188370  ...       4.3       3.7       3.8
# 3    Bennouna  Z01-S07-G01 -13.185620  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.167180  ...       4.2       3.6       3.8
# ..        ...          ...        ...  ...       ...       ...       ...
# 255     Trari    Trari_269  -5.366667  ...       4.0       4.0       4.2
# 256     Trari    Trari_270  -5.816667  ...       3.6       3.8       4.0
# 257     Trari    Trari_273  -5.366667  ...       4.0       3.9       4.3
# 258     Trari    Trari_274  -5.558611  ...       3.6       3.4       3.6
# 259     Trari    Trari_275  -5.483333  ...       4.0       4.0       4.2
#
# [257 rows x 228 columns]

# %%
data1["CodeSite"][82]
# Out:
# 'Z04-S07-G01'

# %%
data1=data1.drop(82)

# %%
(data1[data1["Cs_longia"]==0]).count
# Out:
# <bound method DataFrame.count of        Source     CodeSite    X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 3    Bennouna  Z01-S07-G01 -13.18562  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.16718  ...       4.2       3.6       3.8
# 5    Bennouna  Z01-S09-G01 -13.20156  ...       4.6       3.8       3.9
# 6    Bennouna  Z01-S11-G01 -13.20700  ...       4.6       3.8       3.9
# 7    Bennouna  Z01-S11-G02 -13.20700  ...       4.6       3.8       3.9
# ..        ...          ...       ...  ...       ...       ...       ...
# 161  Bennouna  Z07-S07-G01  -6.20400  ...       3.1       3.5       3.3
# 163  Bennouna  Z07-S09-G01  -6.91000  ...       2.7       2.9       2.8
# 164  Bennouna  Z07-S10-G01  -6.86400  ...       3.4       3.4       3.6
# 165  Bennouna  Z07-S11-G01  -6.88600  ...       2.8       2.9       2.6
# 166  Bennouna  Z07-S12-G01  -5.00000  ...       3.4       2.8       3.0
#
# [129 rows x 228 columns]>

# %%
data1
# Out:
#        Source     CodeSite     X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0    Bennouna  Z01-S01-G01 -15.911420  ...       5.4       5.5       4.9
# 1    Bennouna  Z01-S05-G01 -13.188370  ...       4.3       3.7       3.8
# 2    Bennouna  Z01-S05-G02 -13.188370  ...       4.3       3.7       3.8
# 3    Bennouna  Z01-S07-G01 -13.185620  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.167180  ...       4.2       3.6       3.8
# ..        ...          ...        ...  ...       ...       ...       ...
# 255     Trari    Trari_269  -5.366667  ...       4.0       4.0       4.2
# 256     Trari    Trari_270  -5.816667  ...       3.6       3.8       4.0
# 257     Trari    Trari_273  -5.366667  ...       4.0       3.9       4.3
# 258     Trari    Trari_274  -5.558611  ...       3.6       3.4       3.6
# 259     Trari    Trari_275  -5.483333  ...       4.0       4.0       4.2
#
# [256 rows x 228 columns]

# %%
data1["CodeSite"][108]
# Out:
# 'Z05-S08-G01'

# %%
data1=data1.drop(108)

# %%
(data1[data1["Cs_longia"]==0]).count
# Out:
# <bound method DataFrame.count of        Source     CodeSite    X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 3    Bennouna  Z01-S07-G01 -13.18562  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.16718  ...       4.2       3.6       3.8
# 5    Bennouna  Z01-S09-G01 -13.20156  ...       4.6       3.8       3.9
# 6    Bennouna  Z01-S11-G01 -13.20700  ...       4.6       3.8       3.9
# 7    Bennouna  Z01-S11-G02 -13.20700  ...       4.6       3.8       3.9
# ..        ...          ...       ...  ...       ...       ...       ...
# 161  Bennouna  Z07-S07-G01  -6.20400  ...       3.1       3.5       3.3
# 163  Bennouna  Z07-S09-G01  -6.91000  ...       2.7       2.9       2.8
# 164  Bennouna  Z07-S10-G01  -6.86400  ...       3.4       3.4       3.6
# 165  Bennouna  Z07-S11-G01  -6.88600  ...       2.8       2.9       2.6
# 166  Bennouna  Z07-S12-G01  -5.00000  ...       3.4       2.8       3.0
#
# [128 rows x 228 columns]>

# %%
data1
# Out:
#        Source     CodeSite     X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0    Bennouna  Z01-S01-G01 -15.911420  ...       5.4       5.5       4.9
# 1    Bennouna  Z01-S05-G01 -13.188370  ...       4.3       3.7       3.8
# 2    Bennouna  Z01-S05-G02 -13.188370  ...       4.3       3.7       3.8
# 3    Bennouna  Z01-S07-G01 -13.185620  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.167180  ...       4.2       3.6       3.8
# ..        ...          ...        ...  ...       ...       ...       ...
# 255     Trari    Trari_269  -5.366667  ...       4.0       4.0       4.2
# 256     Trari    Trari_270  -5.816667  ...       3.6       3.8       4.0
# 257     Trari    Trari_273  -5.366667  ...       4.0       3.9       4.3
# 258     Trari    Trari_274  -5.558611  ...       3.6       3.4       3.6
# 259     Trari    Trari_275  -5.483333  ...       4.0       4.0       4.2
#
# [255 rows x 228 columns]

# %%
data1["CodeSite"][153]
# Out:
# 'Z06-S31-G01'

# %%
data1=data1.drop(153)

# %%
(data1[data1["Cs_longia"]==0]).count
# Out:
# <bound method DataFrame.count of        Source     CodeSite    X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 3    Bennouna  Z01-S07-G01 -13.18562  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.16718  ...       4.2       3.6       3.8
# 5    Bennouna  Z01-S09-G01 -13.20156  ...       4.6       3.8       3.9
# 6    Bennouna  Z01-S11-G01 -13.20700  ...       4.6       3.8       3.9
# 7    Bennouna  Z01-S11-G02 -13.20700  ...       4.6       3.8       3.9
# ..        ...          ...       ...  ...       ...       ...       ...
# 161  Bennouna  Z07-S07-G01  -6.20400  ...       3.1       3.5       3.3
# 163  Bennouna  Z07-S09-G01  -6.91000  ...       2.7       2.9       2.8
# 164  Bennouna  Z07-S10-G01  -6.86400  ...       3.4       3.4       3.6
# 165  Bennouna  Z07-S11-G01  -6.88600  ...       2.8       2.9       2.6
# 166  Bennouna  Z07-S12-G01  -5.00000  ...       3.4       2.8       3.0
#
# [127 rows x 228 columns]>

# %%
data1
# Out:
#        Source     CodeSite     X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0    Bennouna  Z01-S01-G01 -15.911420  ...       5.4       5.5       4.9
# 1    Bennouna  Z01-S05-G01 -13.188370  ...       4.3       3.7       3.8
# 2    Bennouna  Z01-S05-G02 -13.188370  ...       4.3       3.7       3.8
# 3    Bennouna  Z01-S07-G01 -13.185620  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.167180  ...       4.2       3.6       3.8
# ..        ...          ...        ...  ...       ...       ...       ...
# 255     Trari    Trari_269  -5.366667  ...       4.0       4.0       4.2
# 256     Trari    Trari_270  -5.816667  ...       3.6       3.8       4.0
# 257     Trari    Trari_273  -5.366667  ...       4.0       3.9       4.3
# 258     Trari    Trari_274  -5.558611  ...       3.6       3.4       3.6
# 259     Trari    Trari_275  -5.483333  ...       4.0       4.0       4.2
#
# [254 rows x 228 columns]

# %%
(data1[data1["Cs_longia"]==1]).count
# Out:
# <bound method DataFrame.count of        Source     CodeSite     X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0    Bennouna  Z01-S01-G01 -15.911420  ...       5.4       5.5       4.9
# 1    Bennouna  Z01-S05-G01 -13.188370  ...       4.3       3.7       3.8
# 2    Bennouna  Z01-S05-G02 -13.188370  ...       4.3       3.7       3.8
# 8    Bennouna  Z01-S11-G03 -13.207000  ...       4.4       3.6       3.9
# 9    Bennouna  Z01-S12-G01 -13.214230  ...       4.4       3.6       3.8
# ..        ...          ...        ...  ...       ...       ...       ...
# 255     Trari    Trari_269  -5.366667  ...       4.0       4.0       4.2
# 256     Trari    Trari_270  -5.816667  ...       3.6       3.8       4.0
# 257     Trari    Trari_273  -5.366667  ...       4.0       3.9       4.3
# 258     Trari    Trari_274  -5.558611  ...       3.6       3.4       3.6
# 259     Trari    Trari_275  -5.483333  ...       4.0       4.0       4.2
#
# [127 rows x 228 columns]>

# %%
(data1[data1["Cs_longia"]==0]).count
# Out:
# <bound method DataFrame.count of        Source     CodeSite    X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 3    Bennouna  Z01-S07-G01 -13.18562  ...       4.1       3.7       3.9
# 4    Bennouna  Z01-S08-G01 -13.16718  ...       4.2       3.6       3.8
# 5    Bennouna  Z01-S09-G01 -13.20156  ...       4.6       3.8       3.9
# 6    Bennouna  Z01-S11-G01 -13.20700  ...       4.6       3.8       3.9
# 7    Bennouna  Z01-S11-G02 -13.20700  ...       4.6       3.8       3.9
# ..        ...          ...       ...  ...       ...       ...       ...
# 161  Bennouna  Z07-S07-G01  -6.20400  ...       3.1       3.5       3.3
# 163  Bennouna  Z07-S09-G01  -6.91000  ...       2.7       2.9       2.8
# 164  Bennouna  Z07-S10-G01  -6.86400  ...       3.4       3.4       3.6
# 165  Bennouna  Z07-S11-G01  -6.88600  ...       2.8       2.9       2.6
# 166  Bennouna  Z07-S12-G01  -5.00000  ...       3.4       2.8       3.0
#
# [127 rows x 228 columns]>

# %%
 data1.to_excel("cs-longiaN+.xlsx")
