# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/pfe/blob/main/forwardcxpipiens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score

from mlxtend.feature_selection import SequentialFeatureSelector as SFS
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy 
import sklearn.metrics as metrics
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC

# %%
Cl = '/content/cx_pipien equi.xlsx'
data= pd.read_excel(Cl,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True)

# %%
data
# Out:
#        Source     CodeSite     X_long  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0    Bennouna  Z01-S01-G01 -15.911420  ...       5.4       5.5       4.9
# 1    Bennouna  Z01-S05-G01 -13.188370  ...       4.3       3.7       3.8
# 2    Bennouna  Z01-S05-G02 -13.188370  ...       4.3       3.7       3.8
# 3    Bennouna  Z01-S08-G01 -13.167180  ...       4.2       3.6       3.8
# 4    Bennouna  Z01-S11-G01 -13.207000  ...       4.6       3.8       3.9
# ..        ...          ...        ...  ...       ...       ...       ...
# 205     Trari    Trari_254  -5.333333  ...       3.3       3.2       3.1
# 206     Trari    Trari_256  -5.218206  ...       4.3       3.9       3.8
# 207     Trari    Trari_259  -6.033333  ...       3.1       3.4       3.4
# 208     Trari    Trari_263  -5.366667  ...       3.7       3.5       3.5
# 209     Trari    Trari_268  -5.833954  ...       3.5       3.8       3.9
#
# [210 rows x 228 columns]

# %%
del data["Source"]
del data["CodeSite"]

# %%
data
# Out:
#         X_long      Y_lat  Cx_pipiens  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740           0  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950           0  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950           0  ...       4.3       3.7       3.8
# 3   -13.167180  27.157730           1  ...       4.2       3.6       3.8
# 4   -13.207000  27.165000           1  ...       4.6       3.8       3.9
# ..         ...        ...         ...  ...       ...       ...       ...
# 205  -5.333333  35.266667           1  ...       3.3       3.2       3.1
# 206  -5.218206  35.348765           1  ...       4.3       3.9       3.8
# 207  -6.033333  35.466667           1  ...       3.1       3.4       3.4
# 208  -5.366667  35.566667           1  ...       3.7       3.5       3.5
# 209  -5.833954  35.759465           1  ...       3.5       3.8       3.9
#
# [210 rows x 226 columns]

# %%
X1 = data.loc[:, data.columns != 'Cx_pipiens']
y1 = data.Cx_pipiens

# %%
X1
# Out:
#         X_long      Y_lat     Bovins  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 0   -15.911420  23.794740   0.000000  ...       5.4       5.5       4.9
# 1   -13.188370  27.132950   0.000214  ...       4.3       3.7       3.8
# 2   -13.188370  27.132950   0.000214  ...       4.3       3.7       3.8
# 3   -13.167180  27.157730   0.000000  ...       4.2       3.6       3.8
# 4   -13.207000  27.165000   0.000000  ...       4.6       3.8       3.9
# ..         ...        ...        ...  ...       ...       ...       ...
# 205  -5.333333  35.266667  11.136305  ...       3.3       3.2       3.1
# 206  -5.218206  35.348765  24.167864  ...       4.3       3.9       3.8
# 207  -6.033333  35.466667   2.164068  ...       3.1       3.4       3.4
# 208  -5.366667  35.566667   0.000000  ...       3.7       3.5       3.5
# 209  -5.833954  35.759465   0.000000  ...       3.5       3.8       3.9
#
# [210 rows x 225 columns]

# %%
y1
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 205    1
# 206    1
# 207    1
# 208    1
# 209    1
# Name: Cx_pipiens, Length: 210, dtype: int64

# %%
# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
X1,y1,test_size=0.20)

# %%
X_train
# Out:
#         X_long      Y_lat     Bovins  ...  Vent_Oct  Vent_Nov  Vent_Dec
# 190  -4.835395  34.969743   5.965899  ...       3.6       3.8       4.1
# 23   -9.479252  30.353830   0.000000  ...       3.1       3.5       3.1
# 20   -9.561930  30.361240   0.000000  ...       3.4       3.8       3.4
# 106  -4.630000  34.871000  13.769749  ...       3.6       3.9       3.7
# 7   -13.214230  27.166700   0.000000  ...       4.4       3.6       3.8
# ..         ...        ...        ...  ...       ...       ...       ...
# 84   -6.412000  32.737000   4.554679  ...       2.4       2.4       2.5
# 152  -5.066994  32.939082   1.229784  ...       2.9       3.1       2.8
# 74   -6.704939  34.130120   0.000000  ...       3.0       3.2       3.1
# 168  -4.079852  33.686577   0.894904  ...       2.5       3.3       3.0
# 193  -2.373032  35.005734   3.621238  ...       2.8       3.1       3.3
#
# [168 rows x 225 columns]

# %%
y_train
# Out:
# 190    1
# 23     0
# 20     0
# 106    0
# 7      1
#       ..
# 84     0
# 152    1
# 74     0
# 168    1
# 193    1
# Name: Cx_pipiens, Length: 168, dtype: int64

# %%
print('Training dataset shape:', X_train.shape, y_train.shape)
print('Testing dataset shape:', X_test.shape, y_test.shape)
# Out:
# Training dataset shape: (168, 225) (168,)
# Testing dataset shape: (42, 225) (42,)

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
# Build RF classifier to use in feature selection
clf = XGBClassifier(scale_pos_weight=1,learning_rate=0.1,max_depth=7,n_estimators=1000,subsample=0.9,
 colsample_bytree=0.9)
# Build step forward feature selection
sfsT = sfs(clf,
           k_features=8,
           forward=True,
           floating=False,
           verbose=2,
           scoring='roc_auc',
           cv=5)

# Perform SFFS
sfsT = sfsT.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 225 out of 225 | elapsed:  2.0min finished
#
# [2021-08-18 15:29:15] Features: 1/8 -- score: 0.7446583044982699[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 224 out of 224 | elapsed:  1.9min finished
#
# [2021-08-18 15:31:10] Features: 2/8 -- score: 0.7938581314878892[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 223 out of 223 | elapsed:  2.0min finished
#
# [2021-08-18 15:33:10] Features: 3/8 -- score: 0.8443771626297577[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 222 out of 222 | elapsed:  2.1min finished
#
# [2021-08-18 15:35:13] Features: 4/8 -- score: 0.8637110726643599[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 221 out of 221 | elapsed:  2.1min finished
#
# [2021-08-18 15:37:20] Features: 5/8 -- score: 0.8836937716262975[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 220 out of 220 | elapsed:  2.2min finished
#
# [2021-08-18 15:39:32] Features: 6/8 -- score: 0.8855968858131489[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 219 out of 219 | elapsed:  2.3min finished
#
# [2021-08-18 15:41:50] Features: 7/8 -- score: 0.8902681660899653[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 218 out of 218 | elapsed:  2.4min finished
#
# [2021-08-18 15:44:14] Features: 8/8 -- score: 0.8902249134948097

# %%
feat_cols = list(sfsT.k_feature_idx_)
print(feat_cols)
# Out:
# [7, 8, 10, 12, 69, 179, 192, 215]

# %%
feature=X1.columns[feat_cols]

# %%
feature
# Out:
# Index(['Coniferes', 'ZoneAride', 'Lesfeuillus', 'Autres', 'Max_NDVI',
#        'Tmax_Mars', 'Tmin_Avril', 'Vent_Mars'],
#       dtype='object')
